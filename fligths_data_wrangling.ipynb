# %% [markdown]
# ### Installing packages

# %%
# we use natsort package to sort those missing leading zero files 
# !pip install natsort
# Out:
# Requirement already satisfied: natsort in c:\users\tsuki\miniconda3\lib\site-packages (8.4.0)

# %% [markdown]
# ### Defining ANSI codes for colored text prints

# %%
# ANSI escape codes, to make log prints nicer
RED = "\033[31m"
GREEN = "\033[32m"
YELLOW = "\033[33m"
BLUE = "\033[34m"
BOLD = "\033[1m"
ITALIC = "\x1B[3m"
UNDERLINED = "\033[4m"
RESET = "\033[0m"
WHITE_BG    = "\x1b[47m\033[30m" # adding \033[30m makes text black
GREEN_BG    = "\x1b[102m\033[30m" # adding \033[30m makes text black

# https://jakob-bagterp.github.io/colorist-for-python/ansi-escape-codes/standard-16-colors/#bright-colors_2

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import os
from natsort import os_sorted
from datetime import datetime, timedelta

import time
import json
import requests
import zipfile
import warnings 
import urllib3

from dotenv import dotenv_values
from sqlalchemy import create_engine, types, text
from sqlalchemy.dialects.postgresql import JSON as postgres_json

# we'll suppress the "missing SSL certificate" warnings while downloading files
warnings.simplefilter("ignore", urllib3.exceptions.InsecureRequestWarning)

# %% [markdown]
# ## Data Download
# **Sources**
# >Raw Data: https://transtats.bts.gov/PREZIP/
# >Website: https://transtats.bts.gov

# %% [markdown]
# #### working scenario:
# 1. choose a time period for your flights data<br>**NOTE:** usually latest month available is = now - 3 months
# 2. in the first cell:
#     - update `start` for the start date
#     - update `length` for the number of month
# 3. execute all other cells in this notebook
#    <br>**NOTE:** the steps are optimized for multiple months period, but would also work for 1 month
#
# <details>
# <summary style="color:grey">all steps explained</summary>
#
# 1. decide on the period and update `start` and `length` variables
# 2. if not yet created, add 2 folders inside `\da-analytics-engineering-project\` repo:
#      - `downloads`
#      - and `downloads/extracted`
# 3. choose the time period for the flights data (starting month, total number of months)
# 4. under the [transtats URL](https://transtats.bts.gov/PREZIP/) above find files names starting with
# `"On_Time_Reporting_Carrier_On_Time_Performance_1987_present_####_##.zip"`
# - each ZIP file contains a CSV file for **one month** of data (indicated as ####_##)
# - download desired zipfiles to the `downloads` folder
# 5. extract the CSV files into the `downloads/extracted` folder
# </details>

# %%
# 1. Decide on starting month and total number of months
start = '08.2024' # Enter the starting month and the year (MM.YYYY)
length = 3 # How many months do you need?

# %%
# 2. Create folders for the zip files download and for the CSV-files extraction
os.makedirs('./downloads/extracted', exist_ok=True)

# %%
# 3. Create a list of months for the flight

# Generate list of MM.YYYY values for one year
def generate_year_list(start, length):
    start_date = datetime.strptime(start, '%m.%Y')
    return [f"{dt.year}_{dt.month}" for dt in
        (start_date + timedelta(days=31 * i) for i in range(length))]

# MM_YYYY values for the period lenght
year_month_list = generate_year_list(start, length)

print(year_month_list)
# Out:
# ['2024_8', '2024_9', '2024_10']

# %%
type(year_month_list[0])
# Out:
# str

# %%
a = ['2024_8','2024_9','2024_10']
a
# Out:
# ['2024_8', '2024_9', '2024_10']

# %%
# 4. Download ZIP files (~35 seconds per one file)

# Define the URL of the ZIP file
base_url = 'https://transtats.bts.gov/PREZIP/'
download_time = timedelta(0) # for time logging
disk_space_zip = 0

for year_month in year_month_list:

    # Define the URL of the ZIP file and the CSV file
    zip_name = f'On_Time_Reporting_Carrier_On_Time_Performance_1987_present_{year_month}.zip'

    print(f'\n ⏳ This should take {RED}~35 seconds...{RESET}\n\n    ⬇️ {BLUE}downloading:{RESET} {zip_name}')
    print(f'    🐌 {YELLOW}wait for it...{RESET}', end='\r')
    start_time = datetime.now()

    # Send a HTTP request to the specified URL and save the response content
    response = requests.get(base_url+zip_name, verify=False) # we ignore the SSL certificate warnings

    with open(f'./downloads/{zip_name}', 'wb') as file: # save the ZIP in "downloads folder"
        file.write(response.content)
        print(f'    ✅ {GREEN}file saved:{RESET} {zip_name}', end=' ')
    
    # assessing the size of the downloaded file
    file_size = os.path.getsize(f'./downloads/{zip_name}') 
    size_in_mb = file_size / (1024 ** 2) 
    print(f'{GREEN}({size_in_mb:.2f} MB){RESET}\n')
    disk_space_zip += file_size

    # just some fun with basic time logging  
    end_time = datetime.now()
    time_difference = end_time - start_time
    download_time = download_time + time_difference
    if (time_difference.seconds // 60) < 1:
        print(f' 🦊 Actually it took: {YELLOW}{time_difference.seconds % 60} seconds\n{RESET}','-'*80)
    else:
        print(f' 🦊 Actually it took: {YELLOW}{time_difference.seconds // 60} minutes and {time_difference.seconds % 60} seconds\n{RESET}','-'*80)
print(f' 🦊 Total Download Time: {YELLOW}{download_time.seconds // 60} minutes and {download_time.seconds % 60} seconds\n{RESET}')
print(f' 🐹 Used Disk Space: {GREEN}({(disk_space_zip / (1024 ** 2)):.2f} MB){RESET}')
# Out:
#  ⏳ This should take ~35 seconds...
#
#     ⬇️ downloading: On_Time_Reporting_Carrier_On_Time_Performance_1987_present_2024_8.zip
#     ✅ file saved: On_Time_Reporting_Carrier_On_Time_Performance_1987_present_2024_8.zip (29.43 MB)
#
#  🦊 Actually it took: 1 minutes and 16 seconds
#  --------------------------------------------------------------------------------
#
#  ⏳ This should take ~35 seconds...
#
#     ⬇️ downloading: On_Time_Reporting_Carrier_On_Time_Performance_1987_present_2024_9.zip
#     ✅ file saved: On_Time_Reporting_Carrier_On_Time_Performance_1987_present_2024_9.zip (27.12 MB)
#
#  🦊 Actually it took: 35 seconds
#  --------------------------------------------------------------------------------
#
#  ⏳ This should take ~35 seconds...
#
#     ⬇️ downloading: On_Time_Reporting_Carrier_On_Time_Performance_1987_present_2024_10.zip
#     ✅ file saved: On_Time_Reporting_Carrier_On_Time_Performance_1987_present_2024_10.zip (28.06 MB)
#
#  🦊 Actually it took: 36 seconds
#  --------------------------------------------------------------------------------
#  🦊 Total Download Time: 2 minutes and 28 seconds
#
#  🐹 Used Disk Space: (84.60 MB)

# %%
# 5. Extracting CSV files only

disk_space_csv = 0

for year_month in year_month_list:

    # Define the name of the ZIP file and the CSV file
    zip_name = f'On_Time_Reporting_Carrier_On_Time_Performance_1987_present_{year_month}.zip'
    csv_name = f'On_Time_Reporting_Carrier_On_Time_Performance_(1987_present)_{year_month}.csv'

    # Open the downloaded ZIP file
    with zipfile.ZipFile(f'./downloads/{zip_name}', 'r') as zip_ref:
        # Extract the CSV file
        zip_ref.extract(csv_name, path='./downloads/extracted/') # save the CSV in "downloads folder"
        print(f'    🍌 extracted "{csv_name}', end=' ')
        
    # assessing the size of the extracted file
    file_size = os.path.getsize(f'./downloads/extracted/{csv_name}') 
    size_in_mb = file_size / (1024 ** 2) 
    print(f"{GREEN}({size_in_mb:.2f} MB){RESET}\n")
    disk_space_csv += file_size

print('-'*80,f'\n 🐹 Used Disk Space: {GREEN}({(disk_space_csv / (1024 ** 2)):.2f} MB){RESET}')
# Out:
#     🍌 extracted "On_Time_Reporting_Carrier_On_Time_Performance_(1987_present)_2024_8.csv (266.99 MB)
#
#     🍌 extracted "On_Time_Reporting_Carrier_On_Time_Performance_(1987_present)_2024_9.csv (250.81 MB)
#
#     🍌 extracted "On_Time_Reporting_Carrier_On_Time_Performance_(1987_present)_2024_10.csv (265.10 MB)
#
# --------------------------------------------------------------------------------
#  🐹 Used Disk Space: (782.89 MB)

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# ### 1. adding all CSV file names to a list

# %%
# Add all file names from the "extracted" folder to a list
file_names = os.listdir('./downloads/extracted/')

# make sure only the data files are in the list
file_names_unordered = [fname for fname in file_names if fname.startswith("On_Time_Reporting_Carrier_On_Time_Performance_(1987_present)_")]

# using os_sorted function (from natsort) - able to sort strings with numbers ['2','1','11']
# sorted(['2','1','11']) # for comparison
data_files = os_sorted(file_names_unordered)

data_files
# Out:
# ['On_Time_Reporting_Carrier_On_Time_Performance_(1987_present)_2024_8.csv',
#  'On_Time_Reporting_Carrier_On_Time_Performance_(1987_present)_2024_9.csv',
#  'On_Time_Reporting_Carrier_On_Time_Performance_(1987_present)_2024_10.csv']

# %%
# we have 110 columns in each CSV...
file_check = pd.read_csv(f'./downloads/extracted/{data_files[0]}', low_memory = False)
file_check.shape
# Out:
# (619025, 110)

# %%
# original column names are not optimal and need renaming...
print(file_check.columns.to_list())
# Out:
# ['Year', 'Quarter', 'Month', 'DayofMonth', 'DayOfWeek', 'FlightDate', 'Reporting_Airline', 'DOT_ID_Reporting_Airline', 'IATA_CODE_Reporting_Airline', 'Tail_Number', 'Flight_Number_Reporting_Airline', 'OriginAirportID', 'OriginAirportSeqID', 'OriginCityMarketID', 'Origin', 'OriginCityName', 'OriginState', 'OriginStateFips', 'OriginStateName', 'OriginWac', 'DestAirportID', 'DestAirportSeqID', 'DestCityMarketID', 'Dest', 'DestCityName', 'DestState', 'DestStateFips', 'DestStateName', 'DestWac', 'CRSDepTime', 'DepTime', 'DepDelay', 'DepDelayMinutes', 'DepDel15', 'DepartureDelayGroups', 'DepTimeBlk', 'TaxiOut', 'WheelsOff', 'WheelsOn', 'TaxiIn', 'CRSArrTime', 'ArrTime', 'ArrDelay', 'ArrDelayMinutes', 'ArrDel15', 'ArrivalDelayGroups', 'ArrTimeBlk', 'Cancelled', 'CancellationCode', 'Diverted', 'CRSElapsedTime', 'ActualElapsedTime', 'AirTime', 'Flights', 'Distance', 'DistanceGroup', 'CarrierDelay', 'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay', 'FirstDepTime', 'TotalAddGTime', 'LongestAddGTime', 'DivAirportLandings', 'DivReachedDest', 'DivActualElapsedTime', 'DivArrDelay', 'DivDistance', 'Div1Airport', 'Div1AirportID', 'Div1AirportSeqID', 'Div1WheelsOn', 'Div1TotalGTime', 'Div1LongestGTime', 'Div1WheelsOff', 'Div1TailNum', 'Div2Airport', 'Div2AirportID', 'Div2AirportSeqID', 'Div2WheelsOn', 'Div2TotalGTime', 'Div2LongestGTime', 'Div2WheelsOff', 'Div2TailNum', 'Div3Airport', 'Div3AirportID', 'Div3AirportSeqID', 'Div3WheelsOn', 'Div3TotalGTime', 'Div3LongestGTime', 'Div3WheelsOff', 'Div3TailNum', 'Div4Airport', 'Div4AirportID', 'Div4AirportSeqID', 'Div4WheelsOn', 'Div4TotalGTime', 'Div4LongestGTime', 'Div4WheelsOff', 'Div4TailNum', 'Div5Airport', 'Div5AirportID', 'Div5AirportSeqID', 'Div5WheelsOn', 'Div5TotalGTime', 'Div5LongestGTime', 'Div5WheelsOff', 'Div5TailNum', 'Unnamed: 109']

# %% [markdown]
# ### 2. Defining functions
# <font size=4>
# <ul><li>column filter<li>renaming columns<li>changing data types</ul>
# </font>

# %%
# select columns to keep
def cols_to_keep(flights_raw):
    columns_to_keep = [
        "FlightDate",
        "DepTime",
        "CRSDepTime",
        "DepDelay",
        "ArrTime",
        "CRSArrTime",
        "ArrDelay",
        "Reporting_Airline",
        "Tail_Number",
        "Flight_Number_Reporting_Airline",
        "Origin",
        "Dest",
        "AirTime",
        "ActualElapsedTime",
        "Distance",
        "Cancelled",
        "Diverted",
    ]
    flights = flights_raw.loc[:, columns_to_keep]
    return flights

# %%
# rename columns
def rename_cols(flights):
    new_column_names = {
        'FlightDate': 'flight_date',
        'DepTime': 'dep_time',
        'CRSDepTime': 'sched_dep_time',
        'DepDelay': 'dep_delay',
        'ArrTime': 'arr_time',
        'CRSArrTime': 'sched_arr_time',
        'ArrDelay': 'arr_delay',
        'Reporting_Airline': 'airline',
        'Tail_Number': 'tail_number',
        'Flight_Number_Reporting_Airline': 'flight_number',
        'Origin': 'origin',
        'Dest': 'dest',
        'AirTime': 'air_time',
        'ActualElapsedTime': 'actual_elapsed_time',
        'Distance': 'distance',
        'Cancelled': 'cancelled',
        'Diverted': 'diverted'
    }
    flights.rename(columns=new_column_names, inplace=True)
    return flights

# %%
# change datatype
def change_dtypes(flights):
    types_change = {
        'flight_date': 'datetime64[ns]',
        'dep_time': 'Int16',
        'sched_dep_time': 'Int16',
        'dep_delay': 'Int16',
        'arr_time': 'Int16',
        'sched_arr_time': 'Int16',
        'arr_delay': 'Int16',
        'airline': 'O',
        'tail_number': 'O',
        'flight_number': 'Int16',
        'origin': 'O',
        'dest': 'O',
        'air_time': 'Int16',
        'actual_elapsed_time': 'Int16',
        'distance': 'Int16',
        'cancelled': 'Int16',
        'diverted': 'Int16'
    }
    flights = flights.astype(types_change)
    return flights

# %% [markdown]
# ### 3. for-loop over the `data_files` list:
# <font size=4>
# <ol>
# <li>reading a CSV as dataframe
# <li>filtering columns
# <li>renaming columns
# <li>changing data types
# <li>append dataframe to a list of dataframes
# </ol>
# </font>

# %%
data_files
# Out:
# ['On_Time_Reporting_Carrier_On_Time_Performance_(1987_present)_2024_8.csv',
#  'On_Time_Reporting_Carrier_On_Time_Performance_(1987_present)_2024_9.csv',
#  'On_Time_Reporting_Carrier_On_Time_Performance_(1987_present)_2024_10.csv']

# %%
# list for separate dataframes
flights_list = []

#  loop over the extracted csv files and execute functions 
for file in data_files:
    print(file)
    # 1. read as a dataframe
    print('reading...', end=" ")
    flights_raw = pd.read_csv(f'./downloads/extracted/{file}', low_memory = False) 

    # 2.select columns to keep
    flights_select = cols_to_keep(flights_raw) 
    print('filter colums...', end=" ")
    
    # 3. rename columns
    flights_rename = rename_cols(flights_select) 
    print('rename colums...', end=" ")

    # 4. change data types
    flights_dtypes = change_dtypes(flights_rename) 
    print('change dtypes...', end=" ")
    
    # 5. add to the list of dateframes
    flights_list.append(flights_dtypes) 
    print(f'✅ {GREEN}appended to flight_list{RESET}\n')
    
print(f'Done. The list has {len(flights_list)} elements')
# Out:
# On_Time_Reporting_Carrier_On_Time_Performance_(1987_present)_2024_8.csv
# reading... filter colums... rename colums... change dtypes... ✅ appended to flight_list
#
# On_Time_Reporting_Carrier_On_Time_Performance_(1987_present)_2024_9.csv
# reading... filter colums... rename colums... change dtypes... ✅ appended to flight_list
#
# On_Time_Reporting_Carrier_On_Time_Performance_(1987_present)_2024_10.csv
# reading... filter colums... rename colums... change dtypes... ✅ appended to flight_list
#
# Done. The list has 3 elements

# %%
# 6. concatenate the list of dataframes to a one dataframe
flights_all = pd.concat(flights_list)

# %%
# sort dataframe 
flights_all.sort_values(['flight_date','sched_dep_time'], inplace=True)
flights_all
# Out:
#        flight_date  dep_time  sched_dep_time  dep_delay  arr_time  \
# 220313  2024-08-01       201               7        114       724
# 79401   2024-08-01        32              13         19       641
# 296185  2024-08-01        10              15         -5       529
# 591174  2024-08-01        47              15         32       502
# 591191  2024-08-01        46              15         31       653
# ...            ...       ...             ...        ...       ...
# 610986  2024-10-31      2359            2359          0       509
# 611370  2024-10-31      2352            2359         -7       454
# 611564  2024-10-31        11            2359         12       537
# 612328  2024-10-31         4            2359          5       557
# 612504  2024-10-31      2354            2359         -5       510
#
#         sched_arr_time  arr_delay airline tail_number  flight_number origin  \
# 220313             543        101      F9      N350FR           4000    SFO
# 79401              609         32      AA      N181UW           2102    SEA
# 296185             543        -14      NK      N622NK            326    LAX
# 591174             411         51      UA      N36472           1162    BQN
# 591191             630         23      UA      N44501           1139    SFO
# ...                ...        ...     ...         ...            ...    ...
# 610986             536        -27      UA      N37542           2102    LAS
# 611370             513        -19      UA      N38424           1712    DEN
# 611564             548        -11      UA      N18223           1490    PDX
# 612328             611        -14      UA      N773UA            476    SFO
# 612504             539        -29      UA      N64844            297    DEN
#
#        dest  air_time  actual_elapsed_time  distance  cancelled  diverted
# 220313  DFW       178                  203      1464          0         0
# 79401   DFW       199                  249      1660          0         0
# 296185  IAH       176                  199      1379          0         0
# 591174  EWR       234                  255      1585          0         0
# 591191  ORD       220                  247      1846          0         0
# ...     ...       ...                  ...       ...        ...       ...
# 610986  ORD       169                  190      1514          0         0
# 611370  IAD       157                  182      1452          0         0
# 611564  ORD       191                  206      1739          0         0
# 612328  ORD       197                  233      1846          0         0
# 612504  EWR       171                  196      1605          0         0
#
# [1817144 rows x 17 columns]

# %%
# countercheck the time period
flights_all['flight_date'].min(), flights_all['flight_date'].max()
# Out:
# (Timestamp('2024-08-01 00:00:00'), Timestamp('2024-10-31 00:00:00'))

# %% [markdown]
# # Saving the combined dataset<p><font size=5>(just as a backup)</font>

# %%
# define the file name for the combined CSV file (using period's first and last month)
output_file_name = f'flights_from_{year_month_list[0]}_until_{year_month_list[-1]}.csv'
output_file_name
# Out:
# 'flights_from_2024_8_until_2024_10.csv'

# %%
# create folder 'data'
os.makedirs('./data', exist_ok=True)

# %%
# saving
flights_all.to_csv(f'./data/{output_file_name}', index=False)

print(f' ✅ {GREEN}Combined Dataset Saved:{RESET} {output_file_name}', end=' ')

# assessing the size of the extracted file
file_size = os.path.getsize(f'./data/{output_file_name}') 
size_in_mb = file_size / (1024 ** 2) 
print(f"{GREEN}({size_in_mb:.2f} MB){RESET}\n")

# Get the absolute path
absolute_path = os.path.abspath(f'./data/{output_file_name}')
print(absolute_path)
# Out:
#  ✅ Combined Dataset Saved: flights_from_2024_8_until_2024_10.csv (130.29 MB)
#
# c:\Users\tsuki\Projects\da-08122025-analytics-engineering-project\data\flights_from_2024_8_until_2024_10.csv

# %% [markdown]
# ### We got the data in a dataframe. Now it needs to be loaded into our DB.
#
# _________

# %% [markdown]
# ### Next Steps:
# 1. Reduce your dataframe `flights_all` to 3-5 origin/dest airports affected by the weather event (check if they have weather stations here: https://meteostat.net/en/). You can expand your dataset to include more locations or destinations if this is helpful in your analysis. But keep an eye on the size of your data. Dealing with GBs of raw data can make everything very slow.
# 2. Using the Lecture `03_sql_with_python.ipynb` as an example
#    - load DB credentials from your `.env` file
#    - define a connection string
#    - create an engine (SQLAlchemy)
#    - set the **search_path** to your project schema
#    - define data types as `flights_dtypes` (<font style="color:lime">prepared for you here below</font>)
#    - upload filtered `flights_all` dataframe to your project schema in our database <br>(<font style="color:lime">pass the `dtype=flights_dtypes` argument</font>)
#
# 3. You can create a copy of the table `airports` from the schema `public`<p>HINT:
#    - You could run a query via your SQL Alchemy engine
#    - or to be quick, you can run a query in DBeaver

# %%
# Affected airports
# Tampa International Airport, TPA: meteostart id 72211 (https://meteostat.net/en/station/72211?t=2026-02-13/2026-02-20)
# Tallahassee Airport, TLH: meteostat id 72214 (https://meteostat.net/en/station/72214?t=2026-02-13/2026-02-20)
# Hartsfield-Jackson Atlanta Airport, ATL: meteostat id 72219 (https://meteostat.net/en/station/72219?t=2026-02-13/2026-02-20)
# Charlotte/Douglas International Airport, CLT: meteostat id 72314 (https://meteostat.net/en/station/72314?t=2026-02-13/2026-02-20)

# %%
## add code here...

# %%
from dotenv import dotenv_values

config = dotenv_values()

# define variables for the login
pg_user = config['POSTGRES_USER']  # align the key label with your .env file !
pg_host = config['POSTGRES_HOST']
pg_port = config['POSTGRES_PORT']
pg_db = config['POSTGRES_DB']
pg_schema = config['POSTGRES_SCHEMA']
pg_pass = config['POSTGRES_PASS']

# %%
url = f'postgresql://{pg_user}:{pg_pass}@{pg_host}:{pg_port}/{pg_db}'
url
# Out:
# 'postgresql://alinakhomich:HmHCUg2AIEiIgiIU@data-analytics-course-2.c8g8r1deus2v.eu-central-1.rds.amazonaws.com:5432/nf_da_onl_en_081225'

# %%
engine = create_engine(url, echo=True)

# %%
my_schema = 'below_zero' # update it to your schema

with engine.begin() as conn: 
    result = conn.execute(text(f'SET search_path TO {my_schema};'))
# Out:
# 2026-02-27 14:22:58,780 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2026-02-27 14:22:58,784 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-02-27 14:22:58,832 INFO sqlalchemy.engine.Engine select current_schema()
# 2026-02-27 14:22:58,833 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-02-27 14:22:58,885 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2026-02-27 14:22:58,886 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-02-27 14:22:58,934 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-02-27 14:22:58,935 INFO sqlalchemy.engine.Engine SET search_path TO below_zero;
# 2026-02-27 14:22:58,936 INFO sqlalchemy.engine.Engine [generated in 0.00104s] {}
# 2026-02-27 14:22:58,987 INFO sqlalchemy.engine.Engine COMMIT

# %%
# defining data types for the DB
flights_dtypes = {
    'flight_date': types.DateTime,
    'dep_time': types.Integer,
    'sched_dep_time': types.Integer,
    'dep_delay': types.Integer,
    'arr_time': types.Integer,
    'sched_arr_time': types.Integer,
    'arr_delay': types.Integer,
    'airline': types.String,
    'tail_number': types.String,
    'flight_number': types.Integer,
    'origin': types.String,
    'dest': types.String,
    'air_time': types.Integer,
    'actual_elapsed_time': types.Integer,
    'distance': types.Integer,
    'cancelled': types.Integer,
    'diverted': types.Integer
}

# %%
flights_all.head()
# Out:
#        flight_date  dep_time  sched_dep_time  dep_delay  arr_time  \
# 220313  2024-08-01       201               7        114       724
# 79401   2024-08-01        32              13         19       641
# 296185  2024-08-01        10              15         -5       529
# 591174  2024-08-01        47              15         32       502
# 591191  2024-08-01        46              15         31       653
#
#         sched_arr_time  arr_delay airline tail_number  flight_number origin  \
# 220313             543        101      F9      N350FR           4000    SFO
# 79401              609         32      AA      N181UW           2102    SEA
# 296185             543        -14      NK      N622NK            326    LAX
# 591174             411         51      UA      N36472           1162    BQN
# 591191             630         23      UA      N44501           1139    SFO
#
#        dest  air_time  actual_elapsed_time  distance  cancelled  diverted
# 220313  DFW       178                  203      1464          0         0
# 79401   DFW       199                  249      1660          0         0
# 296185  IAH       176                  199      1379          0         0
# 591174  EWR       234                  255      1585          0         0
# 591191  ORD       220                  247      1846          0         0

# %%
flights_filtered_1 = flights_all.query("origin in ['TPA','TLH','ATL','CLT'] or dest in ['TPA','TLH','ATL','CLT']")
flights_filtered_1.head()
# Out:
#        flight_date  dep_time  sched_dep_time  dep_delay  arr_time  \
# 45322   2024-08-01        50              55         -5       752
# 176662  2024-08-01        50              59         -9       732
# 220395  2024-08-01       108              59          9       614
# 2685    2024-08-01       455             500         -5       602
# 6157    2024-08-01       451             500         -9       600
#
#         sched_arr_time  arr_delay airline tail_number  flight_number origin  \
# 45322              804        -12      AA      N918US           2729    PHX
# 176662             800        -28      DL      N121DZ            857    LAS
# 220395             606          8      F9      N370FR           3294    DEN
# 2685               608         -6      AA      N544UW            580    RDU
# 6157               619        -19      AA      N125UW            701    ATL
#
#        dest  air_time  actual_elapsed_time  distance  cancelled  diverted
# 45322   CLT       207                  242      1773          0         0
# 176662  ATL       204                  222      1747          0         0
# 220395  ATL       154                  186      1199          0         0
# 2685    CLT        46                   67       130          0         0
# 6157    CLT        42                   69       226          0         0

# %%
flights_filtered_1.to_sql(
    name="flights_filtered_1",
    con=engine,
    schema="below_zero",   # ← твой schema
    if_exists="replace",
    index=False,
    dtype=flights_dtypes       # ← вот это обязательно
)
# Out:
# 2026-02-27 14:23:07,897 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-02-27 14:23:07,916 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2026-02-27 14:23:07,916 INFO sqlalchemy.engine.Engine [generated in 0.00098s] {'table_name': 'flights_filtered_1', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'below_zero'}
# 2026-02-27 14:23:07,979 INFO sqlalchemy.engine.Engine
# CREATE TABLE below_zero.flights_filtered_1 (
# 	index BIGINT,
# 	flight_date TIMESTAMP WITHOUT TIME ZONE,
# 	dep_time INTEGER,
# 	sched_dep_time INTEGER,
# 	dep_delay INTEGER,
# 	arr_time INTEGER,
# 	sched_arr_time INTEGER,
# 	arr_delay INTEGER,
# 	airline VARCHAR,
# 	tail_number VARCHAR,
# 	flight_number INTEGER,
# 	origin VARCHAR,
# 	dest VARCHAR,
# 	air_time INTEGER,
# 	actual_elapsed_time INTEGER,
# 	distance INTEGER,
# 	cancelled INTEGER,
# 	diverted INTEGER
# )
#
#
# 2026-02-27 14:23:07,980 INFO sqlalchemy.engine.Engine [no key 0.00143s] {}
# 2026-02-27 14:23:08,029 INFO sqlalchemy.engine.Engine CREATE INDEX ix_below_zero_flights_filtered_1_index ON below_zero.flights_filtered_1 (index)
# 2026-02-27 14:23:08,030 INFO sqlalchemy.engine.Engine [no key 0.00078s] {}
# 2026-02-27 14:23:29,263 INFO sqlalchemy.engine.Engine INSERT INTO below_zero.flights_filtered_1 (index, flight_date, dep_time, sched_dep_time, dep_delay, arr_time, sched_arr_time, arr_delay, airline, tail_number, flight_number, origin, dest, air_time, actual_elapsed_time, distance, cancelled, diverted)  ... 368925 characters truncated ... time__999)s, %(actual_elapsed_time__999)s, %(distance__999)s, %(cancelled__999)s, %(diverted__999)s)
# 2026-02-27 14:23:29,286 INFO sqlalchemy.engine.Engine [generated in 19.98029s (insertmanyvalues) 1/319 (unordered)] {'index__0': 45322, 'actual_elapsed_time__0': 242, 'distance__0': 1773, 'dep_delay__0': -5, 'air_time__0': 207, 'cancelled__0': 0, 'airline__0': 'AA', 'dest__0': 'CLT', 'flight_number__0': 2729, 'diverted__0': 0, 'flight_date__0': datetime.datetime(2024, 8, 1, 0, 0), 'dep_time__0': 50, 'sched_arr_time__0': 804, 'sched_dep_time__0': 55, 'tail_number__0': 'N918US', 'origin__0': 'PHX', 'arr_time__0': 752, 'arr_delay__0': -12, 'index__1': 176662, 'actual_elapsed_time__1': 222, 'distance__1': 1747, 'dep_delay__1': -9, 'air_time__1': 204, 'cancelled__1': 0, 'airline__1': 'DL', 'dest__1': 'ATL', 'flight_number__1': 857, 'diverted__1': 0, 'flight_date__1': datetime.datetime(2024, 8, 1, 0, 0), 'dep_time__1': 50, 'sched_arr_time__1': 800, 'sched_dep_time__1': 59, 'tail_number__1': 'N121DZ', 'origin__1': 'LAS', 'arr_time__1': 732, 'arr_delay__1': -28, 'index__2': 220395, 'actual_elapsed_time__2': 186, 'distance__2': 1199, 'dep_delay__2': 9, 'air_time__2': 154, 'cancelled__2': 0, 'airline__2': 'F9', 'dest__2': 'ATL', 'flight_number__2': 3294, 'diverted__2': 0, 'flight_date__2': datetime.datetime(2024, 8, 1, 0, 0), 'dep_time__2': 108, 'sched_arr_time__2': 606, 'sched_dep_time__2': 59 ... 17900 parameters truncated ... 'air_time__997': 44, 'cancelled__997': 0, 'airline__997': 'DL', 'dest__997': 'SAV', 'flight_number__997': 3191, 'diverted__997': 0, 'flight_date__997': datetime.datetime(2024, 8, 1, 0, 0), 'dep_time__997': 934, 'sched_arr_time__997': 1047, 'sched_dep_time__997': 940, 'tail_number__997': 'N937DZ', 'origin__997': 'ATL', 'arr_time__997': 1034, 'arr_delay__997': -13, 'index__998': 291644, 'actual_elapsed_time__998': 244, 'distance__998': 1747, 'dep_delay__998': 2, 'air_time__998': 213, 'cancelled__998': 0, 'airline__998': 'NK', 'dest__998': 'ATL', 'flight_number__998': 2363, 'diverted__998': 0, 'flight_date__998': datetime.datetime(2024, 8, 1, 0, 0), 'dep_time__998': 942, 'sched_arr_time__998': 1643, 'sched_dep_time__998': 940, 'tail_number__998': 'N634NK', 'origin__998': 'LAS', 'arr_time__998': 1646, 'arr_delay__998': 3, 'index__999': 308182, 'actual_elapsed_time__999': 134, 'distance__999': 842, 'dep_delay__999': -1, 'air_time__999': 106, 'cancelled__999': 0, 'airline__999': 'WN', 'dest__999': 'TPA', 'flight_number__999': 4160, 'diverted__999': 0, 'flight_date__999': datetime.datetime(2024, 8, 1, 0, 0), 'dep_time__999': 939, 'sched_arr_time__999': 1205, 'sched_dep_time__999': 940, 'tail_number__999': 'N559WN', 'origin__999': 'BWI', 'arr_time__999': 1153, 'arr_delay__999': -12}
# 2026-02-27 14:23:29,522 INFO sqlalchemy.engine.Engine INSERT INTO below_zero.flights_filtered_1 (index, flight_date, dep_time, sched_dep_time, dep_delay, arr_time, sched_arr_time, arr_delay, airline, tail_number, flight_number, origin, dest, air_time, actual_elapsed_time, distance, cancelled, diverted)  ... 368925 characters truncated ... time__999)s, %(actual_elapsed_time__999)s, %(distance__999)s, %(cancelled__999)s, %(diverted__999)s)
# 2026-02-27 14:23:29,523 INFO sqlalchemy.engine.Engine [insertmanyvalues 2/319 (unordered)] {'index__0': 309824, 'actual_elapsed_time__0': 81, 'distance__0': 404, 'dep_delay__0': 31, 'air_time__0': 61, 'cancelled__0': 0, 'airline__0': 'WN', 'dest__0': 'ATL', 'flight_number__0': 3714, 'diverted__0': 0, 'flight_date__0': datetime.datetime(2024, 8, 1, 0, 0), 'dep_time__0': 1011, 'sched_arr_time__0': 1115, 'sched_dep_time__0': 940, 'tail_number__0': 'N7887A', 'origin__0': 'MCO', 'arr_time__0': 1132, 'arr_delay__0': 17, 'index__1': 37868, 'actual_elapsed_time__1': 292, 'distance__1': 2125, 'dep_delay__1': 30, 'air_time__1': 261, 'cancelled__1': 0, 'airline__1': 'AA', 'dest__1': 'LAX', 'flight_number__1': 1592, 'diverted__1': 0, 'flight_date__1': datetime.datetime(2024, 8, 1, 0, 0), 'dep_time__1': 1011, 'sched_arr_time__1': 1147, 'sched_dep_time__1': 941, 'tail_number__1': 'N164NN', 'origin__1': 'CLT', 'arr_time__1': 1203, 'arr_delay__1': 16, 'index__2': 182935, 'actual_elapsed_time__2': 137, 'distance__2': 874, 'dep_delay__2': -3, 'air_time__2': 115, 'cancelled__2': 0, 'airline__2': 'DL', 'dest__2': 'SAT', 'flight_number__2': 1059, 'diverted__2': 0, 'flight_date__2': datetime.datetime(2024, 8, 1, 0, 0), 'dep_time__2': 938, 'sched_arr_time__2': 1101, 'sched_dep_time__2': 941 ... 17900 parameters truncated ... 'air_time__997': 64, 'cancelled__997': 0, 'airline__997': 'DL', 'dest__997': 'ATL', 'flight_number__997': 1525, 'diverted__997': 0, 'flight_date__997': datetime.datetime(2024, 8, 1, 0, 0), 'dep_time__997': 1542, 'sched_arr_time__997': 1610, 'sched_dep_time__997': 1435, 'tail_number__997': 'N687DL', 'origin__997': 'TPA', 'arr_time__997': 1711, 'arr_delay__997': 61, 'index__998': 159581, 'actual_elapsed_time__998': 114, 'distance__998': 721, 'dep_delay__998': -7, 'air_time__998': 99, 'cancelled__998': 0, 'airline__998': 'DL', 'dest__998': 'DAL', 'flight_number__998': 512, 'diverted__998': 0, 'flight_date__998': datetime.datetime(2024, 8, 1, 0, 0), 'dep_time__998': 1428, 'sched_arr_time__998': 1542, 'sched_dep_time__998': 1435, 'tail_number__998': 'N986AT', 'origin__998': 'ATL', 'arr_time__998': 1522, 'arr_delay__998': -20, 'index__999': 198224, 'actual_elapsed_time__999': 74, 'distance__999': 300, 'dep_delay__999': -7, 'air_time__999': 51, 'cancelled__999': 0, 'airline__999': 'DL', 'dest__999': 'ATL', 'flight_number__999': 3030, 'diverted__999': 0, 'flight_date__999': datetime.datetime(2024, 8, 1, 0, 0), 'dep_time__999': 1428, 'sched_arr_time__999': 1556, 'sched_dep_time__999': 1435, 'tail_number__999': 'N949AT', 'origin__999': 'GNV', 'arr_time__999': 1542, 'arr_delay__999': -14}
# 2026-02-27 14:23:29,722 INFO sqlalchemy.engine.Engine INSERT INTO below_zero.flights_filtered_1 (index, flight_date, dep_time, sched_dep_time, dep_delay, arr_time, sched_arr_time, arr_delay, airline, tail_number, flight_number, origin, dest, air_time, actual_elapsed_time, distance, cancelled, diverted)  ... 368925 characters truncated ... time__999)s, %(actual_elapsed_time__999)s, %(distance__999)s, %(cancelled__999)s, %(diverted__999)s)
# 2026-02-27 14:23:29,723 INFO sqlalchemy.engine.Engine [insertmanyvalues 3/319 (unordered)] {'index__0': 311692, 'actual_elapsed_time__0': 153, 'distance__0': 1075, 'dep_delay__0': 15, 'air_time__0': 140, 'cancelled__0': 0, 'airline__0': 'WN', 'dest__0': 'MKE', 'flight_number__0': 2401, 'diverted__0': 0, 'flight_date__0': datetime.datetime(2024, 8, 1, 0, 0), 'dep_time__0': 1450, 'sched_arr_time__0': 1620, 'sched_dep_time__0': 1435, 'tail_number__0': 'N8684F', 'origin__0': 'TPA', 'arr_time__0': 1623, 'arr_delay__0': 3, 'index__1': 589791, 'actual_elapsed_time__1': 134, 'distance__1': 689, 'dep_delay__1': 0, 'air_time__1': 96, 'cancelled__1': 0, 'airline__1': 'UA', 'dest__1': 'ATL', 'flight_number__1': 2616, 'diverted__1': 0, 'flight_date__1': datetime.datetime(2024, 8, 1, 0, 0), 'dep_time__1': 1435, 'sched_arr_time__1': 1745, 'sched_dep_time__1': 1435, 'tail_number__1': 'N38727', 'origin__1': 'IAH', 'arr_time__1': 1749, 'arr_delay__1': 4, 'index__2': 591533, 'actual_elapsed_time__2': 119, 'distance__2': 534, 'dep_delay__2': 12, 'air_time__2': 79, 'cancelled__2': 0, 'airline__2': 'UA', 'dest__2': 'IAD', 'flight_number__2': 562, 'diverted__2': 0, 'flight_date__2': datetime.datetime(2024, 8, 1, 0, 0), 'dep_time__2': 1447, 'sched_arr_time__2': 1627, 'sched_dep_time__2': 1435 ... 17900 parameters truncated ... 'air_time__997': 105, 'cancelled__997': 0, 'airline__997': 'NK', 'dest__997': 'DFW', 'flight_number__997': 3054, 'diverted__997': 0, 'flight_date__997': datetime.datetime(2024, 8, 1, 0, 0), 'dep_time__997': 1928, 'sched_arr_time__997': 2051, 'sched_dep_time__997': 1929, 'tail_number__997': 'N929NK', 'origin__997': 'ATL', 'arr_time__997': 2044, 'arr_delay__997': -7, 'index__998': 456250, 'actual_elapsed_time__998': 177, 'distance__998': 541, 'dep_delay__998': 16, 'air_time__998': 83, 'cancelled__998': 0, 'airline__998': '9E', 'dest__998': 'CLT', 'flight_number__998': 5036, 'diverted__998': 0, 'flight_date__998': datetime.datetime(2024, 8, 1, 0, 0), 'dep_time__998': 1945, 'sched_arr_time__998': 2155, 'sched_dep_time__998': 1929, 'tail_number__998': 'N923XJ', 'origin__998': 'JFK', 'arr_time__998': 2242, 'arr_delay__998': 47, 'index__999': 26060, 'actual_elapsed_time__999': 60, 'distance__999': 204, 'dep_delay__999': 66, 'air_time__999': 40, 'cancelled__999': 0, 'airline__999': 'AA', 'dest__999': 'TPA', 'flight_number__999': 231, 'diverted__999': 0, 'flight_date__999': datetime.datetime(2024, 8, 1, 0, 0), 'dep_time__999': 2036, 'sched_arr_time__999': 2045, 'sched_dep_time__999': 1930, 'tail_number__999': 'N702UW', 'origin__999': 'MIA', 'arr_time__999': 2136, 'arr_delay__999': 51}
# 2026-02-27 14:23:29,875 INFO sqlalchemy.engine.Engine INSERT INTO below_zero.flights_filtered_1 (index, flight_date, dep_time, sched_dep_time, dep_delay, arr_time, sched_arr_time, arr_delay, airline, tail_number, flight_number, origin, dest, air_time, actual_elapsed_time, distance, cancelled, diverted)  ... 368925 characters truncated ... time__999)s, %(actual_elapsed_time__999)s, %(distance__999)s, %(cancelled__999)s, %(diverted__999)s)
# 2026-02-27 14:23:29,876 INFO sqlalchemy.engine.Engine [insertmanyvalues 4/319 (unordered)] {'index__0': 35811, 'actual_elapsed_time__0': 127, 'distance__0': 666, 'dep_delay__0': 9, 'air_time__0': 90, 'cancelled__0': 0, 'airline__0': 'AA', 'dest__0': 'ATL', 'flight_number__0': 1524, 'diverted__0': 0, 'flight_date__0': datetime.datetime(2024, 8, 1, 0, 0), 'dep_time__0': 1939, 'sched_arr_time__0': 2200, 'sched_dep_time__0': 1930, 'tail_number__0': 'N128UW', 'origin__0': 'PHL', 'arr_time__0': 2146, 'arr_delay__0': -14, 'index__1': 50236, 'actual_elapsed_time__1': 125, 'distance__1': 594, 'dep_delay__1': -4, 'air_time__1': 86, 'cancelled__1': 0, 'airline__1': 'AA', 'dest__1': 'MIA', 'flight_number__1': 945, 'diverted__1': 0, 'flight_date__1': datetime.datetime(2024, 8, 1, 0, 0), 'dep_time__1': 1926, 'sched_arr_time__1': 2137, 'sched_dep_time__1': 1930, 'tail_number__1': 'N774XF', 'origin__1': 'ATL', 'arr_time__1': 2131, 'arr_delay__1': -6, 'index__2': 70230, 'actual_elapsed_time__2': 286, 'distance__2': 2125, 'dep_delay__2': 6, 'air_time__2': 261, 'cancelled__2': 0, 'airline__2': 'AA', 'dest__2': 'LAX', 'flight_number__2': 3016, 'diverted__2': 0, 'flight_date__2': datetime.datetime(2024, 8, 1, 0, 0), 'dep_time__2': 1936, 'sched_arr_time__2': 2124, 'sched_dep_time__2': 1930 ... 17900 parameters truncated ... 'air_time__997': 246, 'cancelled__997': 0, 'airline__997': 'DL', 'dest__997': 'ATL', 'flight_number__997': 721, 'diverted__997': 0, 'flight_date__997': datetime.datetime(2024, 8, 2, 0, 0), 'dep_time__997': 640, 'sched_arr_time__997': 1413, 'sched_dep_time__997': 645, 'tail_number__997': 'N717TW', 'origin__997': 'SNA', 'arr_time__997': 1428, 'arr_delay__997': 15, 'index__998': 189624, 'actual_elapsed_time__998': 60, 'distance__998': 259, 'dep_delay__998': 0, 'air_time__998': 44, 'cancelled__998': 0, 'airline__998': 'DL', 'dest__998': 'ATL', 'flight_number__998': 2124, 'diverted__998': 0, 'flight_date__998': datetime.datetime(2024, 8, 2, 0, 0), 'dep_time__998': 645, 'sched_arr_time__998': 754, 'sched_dep_time__998': 645, 'tail_number__998': 'N932DZ', 'origin__998': 'CHS', 'arr_time__998': 745, 'arr_delay__998': -9, 'index__999': 206148, 'actual_elapsed_time__999': 124, 'distance__999': 587, 'dep_delay__999': -3, 'air_time__999': 84, 'cancelled__999': 0, 'airline__999': 'DL', 'dest__999': 'TPA', 'flight_number__999': 1279, 'diverted__999': 0, 'flight_date__999': datetime.datetime(2024, 8, 2, 0, 0), 'dep_time__999': 642, 'sched_arr_time__999': 838, 'sched_dep_time__999': 645, 'tail_number__999': 'N360NB', 'origin__999': 'RDU', 'arr_time__999': 846, 'arr_delay__999': 8}
# 2026-02-27 14:23:30,101 INFO sqlalchemy.engine.Engine INSERT INTO below_zero.flights_filtered_1 (index, flight_date, dep_time, sched_dep_time, dep_delay, arr_time, sched_arr_time, arr_delay, airline, tail_number, flight_number, origin, dest, air_time, actual_elapsed_time, distance, cancelled, diverted)  ... 368925 characters truncated ... time__999)s, %(actual_elapsed_time__999)s, %(distance__999)s, %(cancelled__999)s, %(diverted__999)s)
# 2026-02-27 14:23:30,102 INFO sqlalchemy.engine.Engine [insertmanyvalues 5/319 (unordered)] {'index__0': 221211, 'actual_elapsed_time__0': 173, 'distance__0': 1199, 'dep_delay__0': 3, 'air_time__0': 141, 'cancelled__0': 0, 'airline__0': 'F9', 'dest__0': 'ATL', 'flight_number__0': 1450, 'diverted__0': 0, 'flight_date__0': datetime.datetime(2024, 8, 2, 0, 0), 'dep_time__0': 648, 'sched_arr_time__0': 1150, 'sched_dep_time__0': 645, 'tail_number__0': 'N603FR', 'origin__0': 'DEN', 'arr_time__0': 1141, 'arr_delay__0': -9, 'index__1': 271749, 'actual_elapsed_time__1': 86, 'distance__1': 386, 'dep_delay__1': -4, 'air_time__1': 63, 'cancelled__1': 0, 'airline__1': 'MQ', 'dest__1': 'CLT', 'flight_number__1': 3831, 'diverted__1': 0, 'flight_date__1': datetime.datetime(2024, 8, 2, 0, 0), 'dep_time__1': 641, 'sched_arr_time__1': 818, 'sched_dep_time__1': 645, 'tail_number__1': 'N201NN', 'origin__1': 'TLH', 'arr_time__1': 807, 'arr_delay__1': -11, 'index__2': 282221, 'actual_elapsed_time__2': 154, 'distance__2': 907, 'dep_delay__2': -8, 'air_time__2': 134, 'cancelled__2': 0, 'airline__2': 'NK', 'dest__2': 'MSP', 'flight_number__2': 1081, 'diverted__2': 0, 'flight_date__2': datetime.datetime(2024, 8, 2, 0, 0), 'dep_time__2': 637, 'sched_arr_time__2': 822, 'sched_dep_time__2': 645 ... 17900 parameters truncated ... 'air_time__997': 37, 'cancelled__997': 0, 'airline__997': 'OH', 'dest__997': 'CLT', 'flight_number__997': 5274, 'diverted__997': 0, 'flight_date__997': datetime.datetime(2024, 8, 2, 0, 0), 'dep_time__997': 1106, 'sched_arr_time__997': 1228, 'sched_dep_time__997': 1114, 'tail_number__997': 'N619NN', 'origin__997': 'TYS', 'arr_time__997': 1222, 'arr_delay__997': -6, 'index__998': 485011, 'actual_elapsed_time__998': 90, 'distance__998': 322, 'dep_delay__998': -6, 'air_time__998': 54, 'cancelled__998': 0, 'airline__998': 'OH', 'dest__998': 'IAD', 'flight_number__998': 5543, 'diverted__998': 0, 'flight_date__998': datetime.datetime(2024, 8, 2, 0, 0), 'dep_time__998': 1108, 'sched_arr_time__998': 1252, 'sched_dep_time__998': 1114, 'tail_number__998': 'N506AE', 'origin__998': 'CLT', 'arr_time__998': 1238, 'arr_delay__998': -14, 'index__999': 20348, 'actual_elapsed_time__999': 224, 'distance__999': 1520, 'dep_delay__999': 9, 'air_time__999': 200, 'cancelled__999': 0, 'airline__999': 'AA', 'dest__999': 'STT', 'flight_number__999': 2432, 'diverted__999': 0, 'flight_date__999': datetime.datetime(2024, 8, 2, 0, 0), 'dep_time__999': 1124, 'sched_arr_time__999': 1505, 'sched_dep_time__999': 1115, 'tail_number__999': 'N70020', 'origin__999': 'CLT', 'arr_time__999': 1508, 'arr_delay__999': 3}
# 2026-02-27 14:23:30,270 INFO sqlalchemy.engine.Engine INSERT INTO below_zero.flights_filtered_1 (index, flight_date, dep_time, sched_dep_time, dep_delay, arr_time, sched_arr_time, arr_delay, airline, tail_number, flight_number, origin, dest, air_time, actual_elapsed_time, distance, cancelled, diverted)  ... 368925 characters truncated ... time__999)s, %(actual_elapsed_time__999)s, %(distance__999)s, %(cancelled__999)s, %(diverted__999)s)
# 2026-02-27 14:23:30,271 INFO sqlalchemy.engine.Engine [insertmanyvalues 6/319 (unordered)] {'index__0': 33343, 'actual_elapsed_time__0': 72, 'distance__0': 328, 'dep_delay__0': -4, 'air_time__0': 48, 'cancelled__0': 0, 'airline__0': 'AA', 'dest__0': 'JAX', 'flight_number__0': 1449, 'diverted__0': 0, 'flight_date__0': datetime.datetime(2024, 8, 2, 0, 0), 'dep_time__0': 1111, 'sched_arr_time__0': 1243, 'sched_dep_time__0': 1115, 'tail_number__0': 'N553UW', 'origin__0': 'CLT', 'arr_time__0': 1223, 'arr_delay__0': -20, 'index__1': 39966, 'actual_elapsed_time__1': 101, 'distance__1': 460, 'dep_delay__1': -5, 'air_time__1': 66, 'cancelled__1': 0, 'airline__1': 'AA', 'dest__1': 'VPS', 'flight_number__1': 2561, 'diverted__1': 0, 'flight_date__1': datetime.datetime(2024, 8, 2, 0, 0), 'dep_time__1': 1110, 'sched_arr_time__1': 1159, 'sched_dep_time__1': 1115, 'tail_number__1': 'N916NN', 'origin__1': 'CLT', 'arr_time__1': 1151, 'arr_delay__1': -8, 'index__2': 58551, 'actual_elapsed_time__2': 95, 'distance__2': 546, 'dep_delay__2': 18, 'air_time__2': 76, 'cancelled__2': 0, 'airline__2': 'AA', 'dest__2': 'BUF', 'flight_number__2': 1955, 'diverted__2': 0, 'flight_date__2': datetime.datetime(2024, 8, 2, 0, 0), 'dep_time__2': 1133, 'sched_arr_time__2': 1305, 'sched_dep_time__2': 1115 ... 17900 parameters truncated ... 'air_time__997': None, 'cancelled__997': 1, 'airline__997': 'AA', 'dest__997': 'BUF', 'flight_number__997': 2301, 'diverted__997': 0, 'flight_date__997': datetime.datetime(2024, 8, 2, 0, 0), 'dep_time__997': None, 'sched_arr_time__997': 1756, 'sched_dep_time__997': 1615, 'tail_number__997': 'N572UW', 'origin__997': 'CLT', 'arr_time__997': None, 'arr_delay__997': None, 'index__998': 38691, 'actual_elapsed_time__998': 143, 'distance__998': 808, 'dep_delay__998': 2, 'air_time__998': 117, 'cancelled__998': 0, 'airline__998': 'AA', 'dest__998': 'MCI', 'flight_number__998': 1615, 'diverted__998': 0, 'flight_date__998': datetime.datetime(2024, 8, 2, 0, 0), 'dep_time__998': 1617, 'sched_arr_time__998': 1738, 'sched_dep_time__998': 1615, 'tail_number__998': 'N997AA', 'origin__998': 'CLT', 'arr_time__998': 1740, 'arr_delay__998': 2, 'index__999': 64686, 'actual_elapsed_time__999': 118, 'distance__999': 257, 'dep_delay__999': 252, 'air_time__999': 63, 'cancelled__999': 0, 'airline__999': 'AA', 'dest__999': 'RIC', 'flight_number__999': 2843, 'diverted__999': 0, 'flight_date__999': datetime.datetime(2024, 8, 2, 0, 0), 'dep_time__999': 2027, 'sched_arr_time__999': 1724, 'sched_dep_time__999': 1615, 'tail_number__999': 'N163US', 'origin__999': 'CLT', 'arr_time__999': 2225, 'arr_delay__999': 301}
# 2026-02-27 14:23:30,431 INFO sqlalchemy.engine.Engine INSERT INTO below_zero.flights_filtered_1 (index, flight_date, dep_time, sched_dep_time, dep_delay, arr_time, sched_arr_time, arr_delay, airline, tail_number, flight_number, origin, dest, air_time, actual_elapsed_time, distance, cancelled, diverted)  ... 368925 characters truncated ... time__999)s, %(actual_elapsed_time__999)s, %(distance__999)s, %(cancelled__999)s, %(diverted__999)s)
# 2026-02-27 14:23:30,432 INFO sqlalchemy.engine.Engine [insertmanyvalues 7/319 (unordered)] {'index__0': 168637, 'actual_elapsed_time__0': 239, 'distance__0': 404, 'dep_delay__0': 25, 'air_time__0': 79, 'cancelled__0': 0, 'airline__0': 'DL', 'dest__0': 'MCO', 'flight_number__0': 1742, 'diverted__0': 0, 'flight_date__0': datetime.datetime(2024, 8, 2, 0, 0), 'dep_time__0': 1640, 'sched_arr_time__0': 1750, 'sched_dep_time__0': 1615, 'tail_number__0': 'N660DL', 'origin__0': 'ATL', 'arr_time__0': 2039, 'arr_delay__0': 169, 'index__1': 311799, 'actual_elapsed_time__1': 135, 'distance__1': 813, 'dep_delay__1': 5, 'air_time__1': 113, 'cancelled__1': 0, 'airline__1': 'WN', 'dest__1': 'AUS', 'flight_number__1': 2386, 'diverted__1': 0, 'flight_date__1': datetime.datetime(2024, 8, 2, 0, 0), 'dep_time__1': 1620, 'sched_arr_time__1': 1730, 'sched_dep_time__1': 1615, 'tail_number__1': 'N7886A', 'origin__1': 'ATL', 'arr_time__1': 1735, 'arr_delay__1': 5, 'index__2': 311832, 'actual_elapsed_time__2': 118, 'distance__2': 696, 'dep_delay__2': 1, 'air_time__2': 96, 'cancelled__2': 0, 'airline__2': 'WN', 'dest__2': 'HOU', 'flight_number__2': 3649, 'diverted__2': 0, 'flight_date__2': datetime.datetime(2024, 8, 2, 0, 0), 'dep_time__2': 1616, 'sched_arr_time__2': 1720, 'sched_dep_time__2': 1615 ... 17900 parameters truncated ... 'air_time__997': 67, 'cancelled__997': 0, 'airline__997': 'WN', 'dest__997': 'CMH', 'flight_number__997': 2995, 'diverted__997': 0, 'flight_date__997': datetime.datetime(2024, 8, 2, 0, 0), 'dep_time__997': 2205, 'sched_arr_time__997': 2240, 'sched_dep_time__997': 2105, 'tail_number__997': 'N8645A', 'origin__997': 'ATL', 'arr_time__997': 2330, 'arr_delay__997': 50, 'index__998': 311884, 'actual_elapsed_time__998': 92, 'distance__998': 484, 'dep_delay__998': 14, 'air_time__998': 74, 'cancelled__998': 0, 'airline__998': 'WN', 'dest__998': 'STL', 'flight_number__998': 3639, 'diverted__998': 0, 'flight_date__998': datetime.datetime(2024, 8, 2, 0, 0), 'dep_time__998': 2119, 'sched_arr_time__998': 2150, 'sched_dep_time__998': 2105, 'tail_number__998': 'N8783L', 'origin__998': 'ATL', 'arr_time__998': 2151, 'arr_delay__998': 1, 'index__999': 467244, 'actual_elapsed_time__999': 121, 'distance__999': 692, 'dep_delay__999': -12, 'air_time__999': 93, 'cancelled__999': 0, 'airline__999': '9E', 'dest__999': 'ABE', 'flight_number__999': 5467, 'diverted__999': 0, 'flight_date__999': datetime.datetime(2024, 8, 2, 0, 0), 'dep_time__999': 2053, 'sched_arr_time__999': 2309, 'sched_dep_time__999': 2105, 'tail_number__999': 'N376CA', 'origin__999': 'ATL', 'arr_time__999': 2254, 'arr_delay__999': -15}
# 2026-02-27 14:23:30,596 INFO sqlalchemy.engine.Engine INSERT INTO below_zero.flights_filtered_1 (index, flight_date, dep_time, sched_dep_time, dep_delay, arr_time, sched_arr_time, arr_delay, airline, tail_number, flight_number, origin, dest, air_time, actual_elapsed_time, distance, cancelled, diverted)  ... 368925 characters truncated ... time__999)s, %(actual_elapsed_time__999)s, %(distance__999)s, %(cancelled__999)s, %(diverted__999)s)
# 2026-02-27 14:23:30,597 INFO sqlalchemy.engine.Engine [insertmanyvalues 8/319 (unordered)] {'index__0': 468414, 'actual_elapsed_time__0': 65, 'distance__0': 227, 'dep_delay__0': -7, 'air_time__0': 44, 'cancelled__0': 0, 'airline__0': '9E', 'dest__0': 'TRI', 'flight_number__0': 5518, 'diverted__0': 0, 'flight_date__0': datetime.datetime(2024, 8, 2, 0, 0), 'dep_time__0': 2058, 'sched_arr_time__0': 2215, 'sched_dep_time__0': 2105, 'tail_number__0': 'N309PQ', 'origin__0': 'ATL', 'arr_time__0': 2203, 'arr_delay__0': -12, 'index__1': 220821, 'actual_elapsed_time__1': 94, 'distance__1': 404, 'dep_delay__1': 27, 'air_time__1': 58, 'cancelled__1': 0, 'airline__1': 'F9', 'dest__1': 'MCO', 'flight_number__1': 4026, 'diverted__1': 0, 'flight_date__1': datetime.datetime(2024, 8, 2, 0, 0), 'dep_time__1': 2133, 'sched_arr_time__1': 2259, 'sched_dep_time__1': 2106, 'tail_number__1': 'N228FR', 'origin__1': 'ATL', 'arr_time__1': 2307, 'arr_delay__1': 8, 'index__2': 490118, 'actual_elapsed_time__2': 97, 'distance__2': 503, 'dep_delay__2': 3, 'air_time__2': 75, 'cancelled__2': 0, 'airline__2': 'OO', 'dest__2': 'LFT', 'flight_number__2': 3667, 'diverted__2': 0, 'flight_date__2': datetime.datetime(2024, 8, 2, 0, 0), 'dep_time__2': 2109, 'sched_arr_time__2': 2151, 'sched_dep_time__2': 2106 ... 17900 parameters truncated ... 'air_time__997': 210, 'cancelled__997': 0, 'airline__997': 'F9', 'dest__997': 'LAS', 'flight_number__997': 1115, 'diverted__997': 0, 'flight_date__997': datetime.datetime(2024, 8, 3, 0, 0), 'dep_time__997': 1100, 'sched_arr_time__997': 939, 'sched_dep_time__997': 820, 'tail_number__997': 'N706FR', 'origin__997': 'ATL', 'arr_time__997': 1222, 'arr_delay__997': 163, 'index__998': 339318, 'actual_elapsed_time__998': 87, 'distance__998': 361, 'dep_delay__998': 28, 'air_time__998': 65, 'cancelled__998': 0, 'airline__998': 'WN', 'dest__998': 'CLT', 'flight_number__998': 1491, 'diverted__998': 0, 'flight_date__998': datetime.datetime(2024, 8, 3, 0, 0), 'dep_time__998': 848, 'sched_arr_time__998': 955, 'sched_dep_time__998': 820, 'tail_number__998': 'N8619F', 'origin__998': 'BWI', 'arr_time__998': 1015, 'arr_delay__998': 20, 'index__999': 573093, 'actual_elapsed_time__999': None, 'distance__999': 322, 'dep_delay__999': None, 'air_time__999': None, 'cancelled__999': 1, 'airline__999': 'UA', 'dest__999': 'CLT', 'flight_number__999': 1412, 'diverted__999': 0, 'flight_date__999': datetime.datetime(2024, 8, 3, 0, 0), 'dep_time__999': None, 'sched_arr_time__999': 951, 'sched_dep_time__999': 820, 'tail_number__999': None, 'origin__999': 'IAD', 'arr_time__999': None, 'arr_delay__999': None}
# 2026-02-27 14:23:30,775 INFO sqlalchemy.engine.Engine INSERT INTO below_zero.flights_filtered_1 (index, flight_date, dep_time, sched_dep_time, dep_delay, arr_time, sched_arr_time, arr_delay, airline, tail_number, flight_number, origin, dest, air_time, actual_elapsed_time, distance, cancelled, diverted)  ... 368925 characters truncated ... time__999)s, %(actual_elapsed_time__999)s, %(distance__999)s, %(cancelled__999)s, %(diverted__999)s)
# 2026-02-27 14:23:30,776 INFO sqlalchemy.engine.Engine [insertmanyvalues 9/319 (unordered)] {'index__0': 207177, 'actual_elapsed_time__0': 109, 'distance__0': 545, 'dep_delay__0': -6, 'air_time__0': 86, 'cancelled__0': 0, 'airline__0': 'DL', 'dest__0': 'PBI', 'flight_number__0': 1311, 'diverted__0': 0, 'flight_date__0': datetime.datetime(2024, 8, 3, 0, 0), 'dep_time__0': 815, 'sched_arr_time__0': 1010, 'sched_dep_time__0': 821, 'tail_number__0': 'N357DN', 'origin__0': 'ATL', 'arr_time__0': 1004, 'arr_delay__0': -6, 'index__1': 483493, 'actual_elapsed_time__1': 110, 'distance__1': 547, 'dep_delay__1': -7, 'air_time__1': 81, 'cancelled__1': 0, 'airline__1': 'OH', 'dest__1': 'ATL', 'flight_number__1': 5489, 'diverted__1': 0, 'flight_date__1': datetime.datetime(2024, 8, 3, 0, 0), 'dep_time__1': 814, 'sched_arr_time__1': 1020, 'sched_dep_time__1': 821, 'tail_number__1': 'N507AE', 'origin__1': 'DCA', 'arr_time__1': 1004, 'arr_delay__1': -16, 'index__2': 193844, 'actual_elapsed_time__2': 128, 'distance__2': 813, 'dep_delay__2': -7, 'air_time__2': 104, 'cancelled__2': 0, 'airline__2': 'DL', 'dest__2': 'ATL', 'flight_number__2': 2899, 'diverted__2': 0, 'flight_date__2': datetime.datetime(2024, 8, 3, 0, 0), 'dep_time__2': 815, 'sched_arr_time__2': 1140, 'sched_dep_time__2': 822 ... 17900 parameters truncated ... 'air_time__997': 80, 'cancelled__997': 0, 'airline__997': 'F9', 'dest__997': 'MCO', 'flight_number__997': 1564, 'diverted__997': 0, 'flight_date__997': datetime.datetime(2024, 8, 3, 0, 0), 'dep_time__997': 1415, 'sched_arr_time__997': 1517, 'sched_dep_time__997': 1335, 'tail_number__997': 'N341FR', 'origin__997': 'ATL', 'arr_time__997': 1615, 'arr_delay__997': 58, 'index__998': 339767, 'actual_elapsed_time__998': 101, 'distance__998': 547, 'dep_delay__998': 3, 'air_time__998': 79, 'cancelled__998': 0, 'airline__998': 'WN', 'dest__998': 'ATL', 'flight_number__998': 979, 'diverted__998': 0, 'flight_date__998': datetime.datetime(2024, 8, 3, 0, 0), 'dep_time__998': 1338, 'sched_arr_time__998': 1525, 'sched_dep_time__998': 1335, 'tail_number__998': 'N7849A', 'origin__998': 'DCA', 'arr_time__998': 1519, 'arr_delay__998': -6, 'index__999': 341617, 'actual_elapsed_time__999': 180, 'distance__999': 920, 'dep_delay__999': 2, 'air_time__999': 143, 'cancelled__999': 0, 'airline__999': 'WN', 'dest__999': 'TPA', 'flight_number__999': 2380, 'diverted__999': 0, 'flight_date__999': datetime.datetime(2024, 8, 3, 0, 0), 'dep_time__999': 1337, 'sched_arr_time__999': 1605, 'sched_dep_time__999': 1335, 'tail_number__999': 'N8854Q', 'origin__999': 'PHL', 'arr_time__999': 1637, 'arr_delay__999': 32}
# 2026-02-27 14:23:30,977 INFO sqlalchemy.engine.Engine INSERT INTO below_zero.flights_filtered_1 (index, flight_date, dep_time, sched_dep_time, dep_delay, arr_time, sched_arr_time, arr_delay, airline, tail_number, flight_number, origin, dest, air_time, actual_elapsed_time, distance, cancelled, diverted)  ... 368925 characters truncated ... time__999)s, %(actual_elapsed_time__999)s, %(distance__999)s, %(cancelled__999)s, %(diverted__999)s)
# 2026-02-27 14:23:30,978 INFO sqlalchemy.engine.Engine [insertmanyvalues 10/319 (unordered)] {'index__0': 453806, 'actual_elapsed_time__0': 66, 'distance__0': 241, 'dep_delay__0': 33, 'air_time__0': 46, 'cancelled__0': 0, 'airline__0': '9E', 'dest__0': 'GTR', 'flight_number__0': 4953, 'diverted__0': 0, 'flight_date__0': datetime.datetime(2024, 8, 3, 0, 0), 'dep_time__0': 1408, 'sched_arr_time__0': 1345, 'sched_dep_time__0': 1335, 'tail_number__0': 'N297PQ', 'origin__0': 'ATL', 'arr_time__0': 1414, 'arr_delay__0': 29, 'index__1': 132652, 'actual_elapsed_time__1': 177, 'distance__1': 1199, 'dep_delay__1': 279, 'air_time__1': 143, 'cancelled__1': 0, 'airline__1': 'DL', 'dest__1': 'ATL', 'flight_number__1': 706, 'diverted__1': 0, 'flight_date__1': datetime.datetime(2024, 8, 3, 0, 0), 'dep_time__1': 1815, 'sched_arr_time__1': 1845, 'sched_dep_time__1': 1336, 'tail_number__1': 'N397DN', 'origin__1': 'DEN', 'arr_time__1': 2312, 'arr_delay__1': 267, 'index__2': 48266, 'actual_elapsed_time__2': 257, 'distance__2': 1736, 'dep_delay__2': -2, 'air_time__2': 207, 'cancelled__2': 0, 'airline__2': 'AA', 'dest__2': 'CLT', 'flight_number__2': 848, 'diverted__2': 0, 'flight_date__2': datetime.datetime(2024, 8, 3, 0, 0), 'dep_time__2': 1335, 'sched_arr_time__2': 1940, 'sched_dep_time__2': 1337 ... 17900 parameters truncated ... 'air_time__997': 53, 'cancelled__997': 0, 'airline__997': 'AA', 'dest__997': 'CMH', 'flight_number__997': 1151, 'diverted__997': 0, 'flight_date__997': datetime.datetime(2024, 8, 3, 0, 0), 'dep_time__997': 2018, 'sched_arr_time__997': 2004, 'sched_dep_time__997': 1842, 'tail_number__997': 'N661AW', 'origin__997': 'CLT', 'arr_time__997': 2133, 'arr_delay__997': 89, 'index__998': 305239, 'actual_elapsed_time__998': 106, 'distance__998': 594, 'dep_delay__998': 196, 'air_time__998': 85, 'cancelled__998': 0, 'airline__998': 'NK', 'dest__998': 'ATL', 'flight_number__998': 969, 'diverted__998': 0, 'flight_date__998': datetime.datetime(2024, 8, 3, 0, 0), 'dep_time__998': 2158, 'sched_arr_time__998': 2044, 'sched_dep_time__998': 1842, 'tail_number__998': 'N966NK', 'origin__998': 'DTW', 'arr_time__998': 2344, 'arr_delay__998': 180, 'index__999': 462832, 'actual_elapsed_time__999': 46, 'distance__999': 134, 'dep_delay__999': 87, 'air_time__999': 30, 'cancelled__999': 0, 'airline__999': '9E', 'dest__999': 'BHM', 'flight_number__999': 5290, 'diverted__999': 0, 'flight_date__999': datetime.datetime(2024, 8, 3, 0, 0), 'dep_time__999': 2009, 'sched_arr_time__999': 1835, 'sched_dep_time__999': 1842, 'tail_number__999': 'N491PX', 'origin__999': 'ATL', 'arr_time__999': 1955, 'arr_delay__999': 80}
# 2026-02-27 14:23:31,160 INFO sqlalchemy.engine.Engine INSERT INTO below_zero.flights_filtered_1 (index, flight_date, dep_time, sched_dep_time, dep_delay, arr_time, sched_arr_time, arr_delay, airline, tail_number, flight_number, origin, dest, air_time, actual_elapsed_time, distance, cancelled, diverted)  ... 368925 characters truncated ... time__999)s, %(actual_elapsed_time__999)s, %(distance__999)s, %(cancelled__999)s, %(diverted__999)s)
# 2026-02-27 14:23:31,161 INFO sqlalchemy.engine.Engine [insertmanyvalues 11/319 (unordered)] {'index__0': 198982, 'actual_elapsed_time__0': 72, 'distance__0': 306, 'dep_delay__0': 1, 'air_time__0': 52, 'cancelled__0': 0, 'airline__0': 'DL', 'dest__0': 'ATL', 'flight_number__0': 3050, 'diverted__0': 0, 'flight_date__0': datetime.datetime(2024, 8, 3, 0, 0), 'dep_time__0': 1844, 'sched_arr_time__0': 2010, 'sched_dep_time__0': 1843, 'tail_number__0': 'N899AT', 'origin__0': 'GSO', 'arr_time__0': 1956, 'arr_delay__0': -14, 'index__1': 216952, 'actual_elapsed_time__1': 88, 'distance__1': 214, 'dep_delay__1': 25, 'air_time__1': 54, 'cancelled__1': 0, 'airline__1': 'DL', 'dest__1': 'ATL', 'flight_number__1': 3112, 'diverted__1': 0, 'flight_date__1': datetime.datetime(2024, 8, 3, 0, 0), 'dep_time__1': 1908, 'sched_arr_time__1': 1957, 'sched_dep_time__1': 1843, 'tail_number__1': 'N957DZ', 'origin__1': 'SAV', 'arr_time__1': 2036, 'arr_delay__1': 39, 'index__2': 33535, 'actual_elapsed_time__2': 138, 'distance__2': 728, 'dep_delay__2': 325, 'air_time__2': 112, 'cancelled__2': 0, 'airline__2': 'AA', 'dest__2': 'BOS', 'flight_number__2': 1453, 'diverted__2': 0, 'flight_date__2': datetime.datetime(2024, 8, 3, 0, 0), 'dep_time__2': 10, 'sched_arr_time__2': 2057, 'sched_dep_time__2': 1845 ... 17900 parameters truncated ... 'air_time__997': 34, 'cancelled__997': 0, 'airline__997': 'DL', 'dest__997': 'ATL', 'flight_number__997': 1146, 'diverted__997': 0, 'flight_date__997': datetime.datetime(2024, 8, 4, 0, 0), 'dep_time__997': 652, 'sched_arr_time__997': 758, 'sched_dep_time__997': 656, 'tail_number__997': 'N941DZ', 'origin__997': 'GSP', 'arr_time__997': 747, 'arr_delay__997': -11, 'index__998': 295556, 'actual_elapsed_time__998': 87, 'distance__998': 488, 'dep_delay__998': 98, 'air_time__998': 73, 'cancelled__998': 0, 'airline__998': 'NK', 'dest__998': 'MSY', 'flight_number__998': 3160, 'diverted__998': 0, 'flight_date__998': datetime.datetime(2024, 8, 4, 0, 0), 'dep_time__998': 837, 'sched_arr_time__998': 738, 'sched_dep_time__998': 659, 'tail_number__998': 'N638NK', 'origin__998': 'TPA', 'arr_time__998': 904, 'arr_delay__998': 86, 'index__999': 404, 'actual_elapsed_time__999': 132, 'distance__999': 651, 'dep_delay__999': 5, 'air_time__999': 94, 'cancelled__999': 0, 'airline__999': 'AA', 'dest__999': 'CLT', 'flight_number__999': 491, 'diverted__999': 0, 'flight_date__999': datetime.datetime(2024, 8, 4, 0, 0), 'dep_time__999': 705, 'sched_arr_time__999': 1003, 'sched_dep_time__999': 700, 'tail_number__999': 'N926UW', 'origin__999': 'MKE', 'arr_time__999': 1017, 'arr_delay__999': 14}
# 2026-02-27 14:23:31,340 INFO sqlalchemy.engine.Engine INSERT INTO below_zero.flights_filtered_1 (index, flight_date, dep_time, sched_dep_time, dep_delay, arr_time, sched_arr_time, arr_delay, airline, tail_number, flight_number, origin, dest, air_time, actual_elapsed_time, distance, cancelled, diverted)  ... 368925 characters truncated ... time__999)s, %(actual_elapsed_time__999)s, %(distance__999)s, %(cancelled__999)s, %(diverted__999)s)
# 2026-02-27 14:23:31,341 INFO sqlalchemy.engine.Engine [insertmanyvalues 12/319 (unordered)] {'index__0': 5666, 'actual_elapsed_time__0': None, 'distance__0': 130, 'dep_delay__0': None, 'air_time__0': None, 'cancelled__0': 1, 'airline__0': 'AA', 'dest__0': 'CLT', 'flight_number__0': 683, 'diverted__0': 0, 'flight_date__0': datetime.datetime(2024, 8, 4, 0, 0), 'dep_time__0': None, 'sched_arr_time__0': 808, 'sched_dep_time__0': 700, 'tail_number__0': 'N584UW', 'origin__0': 'RDU', 'arr_time__0': None, 'arr_delay__0': None, 'index__1': 14453, 'actual_elapsed_time__1': 142, 'distance__1': 920, 'dep_delay__1': -1, 'air_time__1': 119, 'cancelled__1': 0, 'airline__1': 'AA', 'dest__1': 'PHL', 'flight_number__1': 1806, 'diverted__1': 0, 'flight_date__1': datetime.datetime(2024, 8, 4, 0, 0), 'dep_time__1': 659, 'sched_arr_time__1': 934, 'sched_dep_time__1': 700, 'tail_number__1': 'N125UW', 'origin__1': 'TPA', 'arr_time__1': 921, 'arr_delay__1': -13, 'index__2': 17068, 'actual_elapsed_time__2': 150, 'distance__2': 920, 'dep_delay__2': -3, 'air_time__2': 130, 'cancelled__2': 0, 'airline__2': 'AA', 'dest__2': 'TPA', 'flight_number__2': 2338, 'diverted__2': 0, 'flight_date__2': datetime.datetime(2024, 8, 4, 0, 0), 'dep_time__2': 657, 'sched_arr_time__2': 937, 'sched_dep_time__2': 700 ... 17900 parameters truncated ... 'air_time__997': 61, 'cancelled__997': 0, 'airline__997': 'OH', 'dest__997': 'DAY', 'flight_number__997': 5385, 'diverted__997': 0, 'flight_date__997': datetime.datetime(2024, 8, 4, 0, 0), 'dep_time__997': 1117, 'sched_arr_time__997': 1300, 'sched_dep_time__997': 1120, 'tail_number__997': 'N604NN', 'origin__997': 'CLT', 'arr_time__997': 1246, 'arr_delay__997': -14, 'index__998': 569943, 'actual_elapsed_time__998': 169, 'distance__998': 1012, 'dep_delay__998': 145, 'air_time__998': 141, 'cancelled__998': 0, 'airline__998': 'UA', 'dest__998': 'TPA', 'flight_number__998': 2668, 'diverted__998': 0, 'flight_date__998': datetime.datetime(2024, 8, 4, 0, 0), 'dep_time__998': 1345, 'sched_arr_time__998': 1511, 'sched_dep_time__998': 1120, 'tail_number__998': 'N47281', 'origin__998': 'ORD', 'arr_time__998': 1734, 'arr_delay__998': 143, 'index__999': 57193, 'actual_elapsed_time__999': 138, 'distance__999': 940, 'dep_delay__999': -5, 'air_time__999': 122, 'cancelled__999': 0, 'airline__999': 'AA', 'dest__999': 'OKC', 'flight_number__999': 1917, 'diverted__999': 0, 'flight_date__999': datetime.datetime(2024, 8, 4, 0, 0), 'dep_time__999': 1116, 'sched_arr_time__999': 1302, 'sched_dep_time__999': 1121, 'tail_number__999': 'N108UW', 'origin__999': 'CLT', 'arr_time__999': 1234, 'arr_delay__999': -28}
# 2026-02-27 14:23:31,500 INFO sqlalchemy.engine.Engine INSERT INTO below_zero.flights_filtered_1 (index, flight_date, dep_time, sched_dep_time, dep_delay, arr_time, sched_arr_time, arr_delay, airline, tail_number, flight_number, origin, dest, air_time, actual_elapsed_time, distance, cancelled, diverted)  ... 368925 characters truncated ... time__999)s, %(actual_elapsed_time__999)s, %(distance__999)s, %(cancelled__999)s, %(diverted__999)s)
# 2026-02-27 14:23:31,501 INFO sqlalchemy.engine.Engine [insertmanyvalues 13/319 (unordered)] {'index__0': 132653, 'actual_elapsed_time__0': 173, 'distance__0': 1199, 'dep_delay__0': 24, 'air_time__0': 157, 'cancelled__0': 0, 'airline__0': 'DL', 'dest__0': 'DEN', 'flight_number__0': 706, 'diverted__0': 0, 'flight_date__0': datetime.datetime(2024, 8, 4, 0, 0), 'dep_time__0': 1145, 'sched_arr_time__0': 1231, 'sched_dep_time__0': 1121, 'tail_number__0': 'N104DN', 'origin__0': 'ATL', 'arr_time__0': 1238, 'arr_delay__0': 7, 'index__1': 188786, 'actual_elapsed_time__1': 59, 'distance__1': 240, 'dep_delay__1': 8, 'air_time__1': 42, 'cancelled__1': 0, 'airline__1': 'DL', 'dest__1': 'ATL', 'flight_number__1': 2100, 'diverted__1': 0, 'flight_date__1': datetime.datetime(2024, 8, 4, 0, 0), 'dep_time__1': 1129, 'sched_arr_time__1': 1331, 'sched_dep_time__1': 1121, 'tail_number__1': 'N926AT', 'origin__1': 'ECP', 'arr_time__1': 1328, 'arr_delay__1': -3, 'index__2': 265541, 'actual_elapsed_time__2': 74, 'distance__2': 335, 'dep_delay__2': 11, 'air_time__2': 51, 'cancelled__2': 0, 'airline__2': 'MQ', 'dest__2': 'CLT', 'flight_number__2': 3620, 'diverted__2': 0, 'flight_date__2': datetime.datetime(2024, 8, 4, 0, 0), 'dep_time__2': 1132, 'sched_arr_time__2': 1254, 'sched_dep_time__2': 1121 ... 17900 parameters truncated ... 'air_time__997': 57, 'cancelled__997': 0, 'airline__997': 'OO', 'dest__997': 'CRW', 'flight_number__997': 3811, 'diverted__997': 0, 'flight_date__997': datetime.datetime(2024, 8, 4, 0, 0), 'dep_time__997': 1625, 'sched_arr_time__997': 1746, 'sched_dep_time__997': 1620, 'tail_number__997': 'N804SK', 'origin__997': 'ATL', 'arr_time__997': 1816, 'arr_delay__997': 30, 'index__998': 571127, 'actual_elapsed_time__998': 196, 'distance__998': 1337, 'dep_delay__998': 16, 'air_time__998': 172, 'cancelled__998': 0, 'airline__998': 'UA', 'dest__998': 'DEN', 'flight_number__998': 1377, 'diverted__998': 0, 'flight_date__998': datetime.datetime(2024, 8, 4, 0, 0), 'dep_time__998': 1636, 'sched_arr_time__998': 1802, 'sched_dep_time__998': 1620, 'tail_number__998': 'N879UA', 'origin__998': 'CLT', 'arr_time__998': 1752, 'arr_delay__998': -10, 'index__999': 571695, 'actual_elapsed_time__999': None, 'distance__999': 1506, 'dep_delay__999': None, 'air_time__999': None, 'cancelled__999': 1, 'airline__999': 'UA', 'dest__999': 'DEN', 'flight_number__999': 540, 'diverted__999': 0, 'flight_date__999': datetime.datetime(2024, 8, 4, 0, 0), 'dep_time__999': None, 'sched_arr_time__999': 1812, 'sched_dep_time__999': 1620, 'tail_number__999': None, 'origin__999': 'TPA', 'arr_time__999': None, 'arr_delay__999': None}
# 2026-02-27 14:23:31,664 INFO sqlalchemy.engine.Engine INSERT INTO below_zero.flights_filtered_1 (index, flight_date, dep_time, sched_dep_time, dep_delay, arr_time, sched_arr_time, arr_delay, airline, tail_number, flight_number, origin, dest, air_time, actual_elapsed_time, distance, cancelled, diverted)  ... 368925 characters truncated ... time__999)s, %(actual_elapsed_time__999)s, %(distance__999)s, %(cancelled__999)s, %(diverted__999)s)
# 2026-02-27 14:23:31,665 INFO sqlalchemy.engine.Engine [insertmanyvalues 14/319 (unordered)] {'index__0': 571945, 'actual_elapsed_time__0': 215, 'distance__0': 1199, 'dep_delay__0': 3, 'air_time__0': 165, 'cancelled__0': 0, 'airline__0': 'UA', 'dest__0': 'DEN', 'flight_number__0': 235, 'diverted__0': 0, 'flight_date__0': datetime.datetime(2024, 8, 4, 0, 0), 'dep_time__0': 1623, 'sched_arr_time__0': 1759, 'sched_dep_time__0': 1620, 'tail_number__0': 'N438UA', 'origin__0': 'ATL', 'arr_time__0': 1758, 'arr_delay__0': -1, 'index__1': 45894, 'actual_elapsed_time__1': None, 'distance__1': 168, 'dep_delay__1': None, 'air_time__1': None, 'cancelled__1': 1, 'airline__1': 'AA', 'dest__1': 'CLT', 'flight_number__1': 2745, 'diverted__1': 0, 'flight_date__1': datetime.datetime(2024, 8, 4, 0, 0), 'dep_time__1': None, 'sched_arr_time__1': 1733, 'sched_dep_time__1': 1621, 'tail_number__1': 'N118US', 'origin__1': 'CHS', 'arr_time__1': None, 'arr_delay__1': None, 'index__2': 57882, 'actual_elapsed_time__2': None, 'distance__2': 1916, 'dep_delay__2': None, 'air_time__2': None, 'cancelled__2': 1, 'airline__2': 'AA', 'dest__2': 'LAS', 'flight_number__2': 1935, 'diverted__2': 0, 'flight_date__2': datetime.datetime(2024, 8, 4, 0, 0), 'dep_time__2': None, 'sched_arr_time__2': 1755, 'sched_dep_time__2': 1621 ... 17900 parameters truncated ... 'air_time__997': 28, 'cancelled__997': 0, 'airline__997': 'DL', 'dest__997': 'HSV', 'flight_number__997': 3065, 'diverted__997': 0, 'flight_date__997': datetime.datetime(2024, 8, 4, 0, 0), 'dep_time__997': 2313, 'sched_arr_time__997': 2109, 'sched_dep_time__997': 2110, 'tail_number__997': 'N978AT', 'origin__997': 'ATL', 'arr_time__997': 2257, 'arr_delay__997': 108, 'index__998': 342754, 'actual_elapsed_time__998': 94, 'distance__998': 484, 'dep_delay__998': 63, 'air_time__998': 71, 'cancelled__998': 0, 'airline__998': 'WN', 'dest__998': 'STL', 'flight_number__998': 3205, 'diverted__998': 0, 'flight_date__998': datetime.datetime(2024, 8, 4, 0, 0), 'dep_time__998': 2213, 'sched_arr_time__998': 2150, 'sched_dep_time__998': 2110, 'tail_number__998': 'N8862Q', 'origin__998': 'ATL', 'arr_time__998': 2247, 'arr_delay__998': 57, 'index__999': 345169, 'actual_elapsed_time__999': 100, 'distance__999': 584, 'dep_delay__999': 108, 'air_time__999': 76, 'cancelled__999': 0, 'airline__999': 'WN', 'dest__999': 'CLT', 'flight_number__999': 3980, 'diverted__999': 0, 'flight_date__999': datetime.datetime(2024, 8, 4, 0, 0), 'dep_time__999': 2258, 'sched_arr_time__999': 2355, 'sched_dep_time__999': 2110, 'tail_number__999': 'N565WN', 'origin__999': 'MDW', 'arr_time__999': 138, 'arr_delay__999': 103}
# 2026-02-27 14:23:31,826 INFO sqlalchemy.engine.Engine INSERT INTO below_zero.flights_filtered_1 (index, flight_date, dep_time, sched_dep_time, dep_delay, arr_time, sched_arr_time, arr_delay, airline, tail_number, flight_number, origin, dest, air_time, actual_elapsed_time, distance, cancelled, diverted)  ... 368925 characters truncated ... time__999)s, %(actual_elapsed_time__999)s, %(distance__999)s, %(cancelled__999)s, %(diverted__999)s)
# 2026-02-27 14:23:31,827 INFO sqlalchemy.engine.Engine [insertmanyvalues 15/319 (unordered)] {'index__0': 202518, 'actual_elapsed_time__0': 116, 'distance__0': 666, 'dep_delay__0': 58, 'air_time__0': 88, 'cancelled__0': 0, 'airline__0': 'DL', 'dest__0': 'PHL', 'flight_number__0': 1174, 'diverted__0': 0, 'flight_date__0': datetime.datetime(2024, 8, 4, 0, 0), 'dep_time__0': 2210, 'sched_arr_time__0': 2316, 'sched_dep_time__0': 2112, 'tail_number__0': 'N338DN', 'origin__0': 'ATL', 'arr_time__0': 6, 'arr_delay__0': 50, 'index__1': 200875, 'actual_elapsed_time__1': 84, 'distance__1': 321, 'dep_delay__1': 28, 'air_time__1': 58, 'cancelled__1': 0, 'airline__1': 'DL', 'dest__1': 'SDF', 'flight_number__1': 1126, 'diverted__1': 0, 'flight_date__1': datetime.datetime(2024, 8, 4, 0, 0), 'dep_time__1': 2142, 'sched_arr_time__1': 2237, 'sched_dep_time__1': 2114, 'tail_number__1': 'N329NW', 'origin__1': 'ATL', 'arr_time__1': 2306, 'arr_delay__1': 29, 'index__2': 48176, 'actual_elapsed_time__2': 267, 'distance__2': 2078, 'dep_delay__2': 3, 'air_time__2': 239, 'cancelled__2': 0, 'airline__2': 'AA', 'dest__2': 'ONT', 'flight_number__2': 845, 'diverted__2': 0, 'flight_date__2': datetime.datetime(2024, 8, 4, 0, 0), 'dep_time__2': 2118, 'sched_arr_time__2': 2300, 'sched_dep_time__2': 2115 ... 17900 parameters truncated ... 'air_time__997': 103, 'cancelled__997': 0, 'airline__997': 'DL', 'dest__997': 'DAL', 'flight_number__997': 441, 'diverted__997': 0, 'flight_date__997': datetime.datetime(2024, 8, 5, 0, 0), 'dep_time__997': 810, 'sched_arr_time__997': 923, 'sched_dep_time__997': 815, 'tail_number__997': 'N970AT', 'origin__997': 'ATL', 'arr_time__997': 906, 'arr_delay__997': -17, 'index__998': 183961, 'actual_elapsed_time__998': None, 'distance__998': 515, 'dep_delay__998': None, 'air_time__998': None, 'cancelled__998': 1, 'airline__998': 'DL', 'dest__998': 'RSW', 'flight_number__998': 1089, 'diverted__998': 0, 'flight_date__998': datetime.datetime(2024, 8, 5, 0, 0), 'dep_time__998': None, 'sched_arr_time__998': 951, 'sched_dep_time__998': 815, 'tail_number__998': 'N684DA', 'origin__998': 'ATL', 'arr_time__998': None, 'arr_delay__998': None, 'index__999': 198375, 'actual_elapsed_time__999': 85, 'distance__999': 453, 'dep_delay__999': -6, 'air_time__999': 66, 'cancelled__999': 0, 'airline__999': 'DL', 'dest__999': 'LIT', 'flight_number__999': 3033, 'diverted__999': 0, 'flight_date__999': datetime.datetime(2024, 8, 5, 0, 0), 'dep_time__999': 809, 'sched_arr_time__999': 848, 'sched_dep_time__999': 815, 'tail_number__999': 'N932AT', 'origin__999': 'ATL', 'arr_time__999': 834, 'arr_delay__999': -14}
# 2026-02-27 14:23:31,992 INFO sqlalchemy.engine.Engine INSERT INTO below_zero.flights_filtered_1 (index, flight_date, dep_time, sched_dep_time, dep_delay, arr_time, sched_arr_time, arr_delay, airline, tail_number, flight_number, origin, dest, air_time, actual_elapsed_time, distance, cancelled, diverted)  ... 368925 characters truncated ... time__999)s, %(actual_elapsed_time__999)s, %(distance__999)s, %(cancelled__999)s, %(diverted__999)s)
# ...
# 2026-02-27 14:24:33,215 INFO sqlalchemy.engine.Engine INSERT INTO below_zero.flights_filtered_1 (index, flight_date, dep_time, sched_dep_time, dep_delay, arr_time, sched_arr_time, arr_delay, airline, tail_number, flight_number, origin, dest, air_time, actual_elapsed_time, distance, cancelled, diverted)  ... 368925 characters truncated ... time__999)s, %(actual_elapsed_time__999)s, %(distance__999)s, %(cancelled__999)s, %(diverted__999)s)
# 2026-02-27 14:24:33,217 INFO sqlalchemy.engine.Engine [insertmanyvalues 315/319 (unordered)] {'index__0': 207792, 'actual_elapsed_time__0': 89, 'distance__0': 453, 'dep_delay__0': -4, 'air_time__0': 65, 'cancelled__0': 0, 'airline__0': 'DL', 'dest__0': 'LIT', 'flight_number__0': 3040, 'diverted__0': 0, 'flight_date__0': datetime.datetime(2024, 10, 30, 0, 0), 'dep_time__0': 1111, 'sched_arr_time__0': 1147, 'sched_dep_time__0': 1115, 'tail_number__0': 'N957DZ', 'origin__0': 'ATL', 'arr_time__0': 1140, 'arr_delay__0': -7, 'index__1': 227190, 'actual_elapsed_time__1': 76, 'distance__1': 373, 'dep_delay__1': -6, 'air_time__1': 57, 'cancelled__1': 0, 'airline__1': 'DL', 'dest__1': 'CVG', 'flight_number__1': 3149, 'diverted__1': 0, 'flight_date__1': datetime.datetime(2024, 10, 30, 0, 0), 'dep_time__1': 1109, 'sched_arr_time__1': 1235, 'sched_dep_time__1': 1115, 'tail_number__1': 'N699DL', 'origin__1': 'ATL', 'arr_time__1': 1225, 'arr_delay__1': -10, 'index__2': 228881, 'actual_elapsed_time__2': 96, 'distance__2': 444, 'dep_delay__2': -5, 'air_time__2': 70, 'cancelled__2': 0, 'airline__2': 'DL', 'dest__2': 'ATL', 'flight_number__2': 3196, 'diverted__2': 0, 'flight_date__2': datetime.datetime(2024, 10, 30, 0, 0), 'dep_time__2': 1110, 'sched_arr_time__2': 1252, 'sched_dep_time__2': 1115 ... 17900 parameters truncated ... 'air_time__997': 32, 'cancelled__997': 0, 'airline__997': 'AA', 'dest__997': 'CLT', 'flight_number__997': 2704, 'diverted__997': 0, 'flight_date__997': datetime.datetime(2024, 10, 30, 0, 0), 'dep_time__997': 1625, 'sched_arr_time__997': 1730, 'sched_dep_time__997': 1622, 'tail_number__997': 'N545UW', 'origin__997': 'RDU', 'arr_time__997': 1726, 'arr_delay__997': -4, 'index__998': 553333, 'actual_elapsed_time__998': 100, 'distance__998': 430, 'dep_delay__998': -4, 'air_time__998': 68, 'cancelled__998': 0, 'airline__998': 'AA', 'dest__998': 'CLE', 'flight_number__998': 1267, 'diverted__998': 0, 'flight_date__998': datetime.datetime(2024, 10, 30, 0, 0), 'dep_time__998': 1619, 'sched_arr_time__998': 1805, 'sched_dep_time__998': 1623, 'tail_number__998': 'N989AN', 'origin__998': 'CLT', 'arr_time__998': 1759, 'arr_delay__998': -6, 'index__999': 115652, 'actual_elapsed_time__999': 286, 'distance__999': 2182, 'dep_delay__999': -9, 'air_time__999': 266, 'cancelled__999': 0, 'airline__999': 'AS', 'dest__999': 'ATL', 'flight_number__999': 492, 'diverted__999': 0, 'flight_date__999': datetime.datetime(2024, 10, 30, 0, 0), 'dep_time__999': 1615, 'sched_arr_time__999': 2359, 'sched_dep_time__999': 1624, 'tail_number__999': 'N294AK', 'origin__999': 'SEA', 'arr_time__999': 1, 'arr_delay__999': 2}
# 2026-02-27 14:24:33,435 INFO sqlalchemy.engine.Engine INSERT INTO below_zero.flights_filtered_1 (index, flight_date, dep_time, sched_dep_time, dep_delay, arr_time, sched_arr_time, arr_delay, airline, tail_number, flight_number, origin, dest, air_time, actual_elapsed_time, distance, cancelled, diverted)  ... 368925 characters truncated ... time__999)s, %(actual_elapsed_time__999)s, %(distance__999)s, %(cancelled__999)s, %(diverted__999)s)
# 2026-02-27 14:24:33,436 INFO sqlalchemy.engine.Engine [insertmanyvalues 316/319 (unordered)] {'index__0': 178002, 'actual_elapsed_time__0': 62, 'distance__0': 214, 'dep_delay__0': -8, 'air_time__0': 43, 'cancelled__0': 0, 'airline__0': 'DL', 'dest__0': 'BNA', 'flight_number__0': 1693, 'diverted__0': 0, 'flight_date__0': datetime.datetime(2024, 10, 30, 0, 0), 'dep_time__0': 1616, 'sched_arr_time__0': 1631, 'sched_dep_time__0': 1624, 'tail_number__0': 'N951DX', 'origin__0': 'ATL', 'arr_time__0': 1618, 'arr_delay__0': -13, 'index__1': 211217, 'actual_elapsed_time__1': 72, 'distance__1': 332, 'dep_delay__1': -9, 'air_time__1': 57, 'cancelled__1': 0, 'airline__1': 'DL', 'dest__1': 'MEM', 'flight_number__1': 852, 'diverted__1': 0, 'flight_date__1': datetime.datetime(2024, 10, 30, 0, 0), 'dep_time__1': 1615, 'sched_arr_time__1': 1641, 'sched_dep_time__1': 1624, 'tail_number__1': 'N940DU', 'origin__1': 'ATL', 'arr_time__1': 1627, 'arr_delay__1': -14, 'index__2': 613834, 'actual_elapsed_time__2': 253, 'distance__2': 1337, 'dep_delay__2': -1, 'air_time__2': 226, 'cancelled__2': 0, 'airline__2': 'UA', 'dest__2': 'DEN', 'flight_number__2': 1377, 'diverted__2': 0, 'flight_date__2': datetime.datetime(2024, 10, 30, 0, 0), 'dep_time__2': 1623, 'sched_arr_time__2': 1820, 'sched_dep_time__2': 1624 ... 17900 parameters truncated ... 'air_time__997': 114, 'cancelled__997': 0, 'airline__997': 'DL', 'dest__997': 'ATL', 'flight_number__997': 550, 'diverted__997': 0, 'flight_date__997': datetime.datetime(2024, 10, 31, 0, 0), 'dep_time__997': 557, 'sched_arr_time__997': 827, 'sched_dep_time__997': 600, 'tail_number__997': 'N397DN', 'origin__997': 'LGA', 'arr_time__997': 808, 'arr_delay__997': -19, 'index__998': 164960, 'actual_elapsed_time__998': 293, 'distance__998': 2182, 'dep_delay__998': -4, 'air_time__998': 258, 'cancelled__998': 0, 'airline__998': 'DL', 'dest__998': 'ATL', 'flight_number__998': 569, 'diverted__998': 0, 'flight_date__998': datetime.datetime(2024, 10, 31, 0, 0), 'dep_time__998': 556, 'sched_arr_time__998': 1345, 'sched_dep_time__998': 600, 'tail_number__998': 'N590NW', 'origin__998': 'SEA', 'arr_time__998': 1349, 'arr_delay__998': 4, 'index__999': 164991, 'actual_elapsed_time__999': 264, 'distance__999': 2139, 'dep_delay__999': -4, 'air_time__999': 242, 'cancelled__999': 0, 'airline__999': 'DL', 'dest__999': 'ATL', 'flight_number__999': 570, 'diverted__999': 0, 'flight_date__999': datetime.datetime(2024, 10, 31, 0, 0), 'dep_time__999': 556, 'sched_arr_time__999': 1332, 'sched_dep_time__999': 600, 'tail_number__999': 'N888DU', 'origin__999': 'SFO', 'arr_time__999': 1320, 'arr_delay__999': -12}
# 2026-02-27 14:24:33,636 INFO sqlalchemy.engine.Engine INSERT INTO below_zero.flights_filtered_1 (index, flight_date, dep_time, sched_dep_time, dep_delay, arr_time, sched_arr_time, arr_delay, airline, tail_number, flight_number, origin, dest, air_time, actual_elapsed_time, distance, cancelled, diverted)  ... 368925 characters truncated ... time__999)s, %(actual_elapsed_time__999)s, %(distance__999)s, %(cancelled__999)s, %(diverted__999)s)
# 2026-02-27 14:24:33,636 INFO sqlalchemy.engine.Engine [insertmanyvalues 317/319 (unordered)] {'index__0': 168908, 'actual_elapsed_time__0': 232, 'distance__0': 1747, 'dep_delay__0': -1, 'air_time__0': 208, 'cancelled__0': 0, 'airline__0': 'DL', 'dest__0': 'ATL', 'flight_number__0': 755, 'diverted__0': 0, 'flight_date__0': datetime.datetime(2024, 10, 31, 0, 0), 'dep_time__0': 559, 'sched_arr_time__0': 1254, 'sched_dep_time__0': 600, 'tail_number__0': 'N102DN', 'origin__0': 'LAS', 'arr_time__0': 1251, 'arr_delay__0': -3, 'index__1': 172542, 'actual_elapsed_time__1': 74, 'distance__1': 425, 'dep_delay__1': -4, 'air_time__1': 61, 'cancelled__1': 0, 'airline__1': 'DL', 'dest__1': 'ATL', 'flight_number__1': 1534, 'diverted__1': 0, 'flight_date__1': datetime.datetime(2024, 10, 31, 0, 0), 'dep_time__1': 556, 'sched_arr_time__1': 829, 'sched_dep_time__1': 600, 'tail_number__1': 'N928DU', 'origin__1': 'MSY', 'arr_time__1': 810, 'arr_delay__1': -19, 'index__2': 173195, 'actual_elapsed_time__2': 93, 'distance__2': 356, 'dep_delay__2': 0, 'air_time__2': 59, 'cancelled__2': 0, 'airline__2': 'DL', 'dest__2': 'ATL', 'flight_number__2': 1552, 'diverted__2': 0, 'flight_date__2': datetime.datetime(2024, 10, 31, 0, 0), 'dep_time__2': 600, 'sched_arr_time__2': 730, 'sched_dep_time__2': 600 ... 17900 parameters truncated ... 'air_time__997': 88, 'cancelled__997': 0, 'airline__997': 'AA', 'dest__997': 'BDL', 'flight_number__997': 1379, 'diverted__997': 0, 'flight_date__997': datetime.datetime(2024, 10, 31, 0, 0), 'dep_time__997': 1100, 'sched_arr_time__997': 1251, 'sched_dep_time__997': 1100, 'tail_number__997': 'N148AN', 'origin__997': 'CLT', 'arr_time__997': 1249, 'arr_delay__997': -2, 'index__998': 535274, 'actual_elapsed_time__998': 128, 'distance__998': 728, 'dep_delay__998': -8, 'air_time__998': 106, 'cancelled__998': 0, 'airline__998': 'AA', 'dest__998': 'CLT', 'flight_number__998': 884, 'diverted__998': 0, 'flight_date__998': datetime.datetime(2024, 10, 31, 0, 0), 'dep_time__998': 1052, 'sched_arr_time__998': 1336, 'sched_dep_time__998': 1100, 'tail_number__998': 'N838NN', 'origin__998': 'BOS', 'arr_time__998': 1300, 'arr_delay__998': -36, 'index__999': 540144, 'actual_elapsed_time__999': 109, 'distance__999': 600, 'dep_delay__999': -4, 'air_time__999': 93, 'cancelled__999': 0, 'airline__999': 'AA', 'dest__999': 'RSW', 'flight_number__999': 1094, 'diverted__999': 0, 'flight_date__999': datetime.datetime(2024, 10, 31, 0, 0), 'dep_time__999': 1056, 'sched_arr_time__999': 1255, 'sched_dep_time__999': 1100, 'tail_number__999': 'N932AM', 'origin__999': 'CLT', 'arr_time__999': 1245, 'arr_delay__999': -10}
# 2026-02-27 14:24:33,834 INFO sqlalchemy.engine.Engine INSERT INTO below_zero.flights_filtered_1 (index, flight_date, dep_time, sched_dep_time, dep_delay, arr_time, sched_arr_time, arr_delay, airline, tail_number, flight_number, origin, dest, air_time, actual_elapsed_time, distance, cancelled, diverted)  ... 368925 characters truncated ... time__999)s, %(actual_elapsed_time__999)s, %(distance__999)s, %(cancelled__999)s, %(diverted__999)s)
# 2026-02-27 14:24:33,835 INFO sqlalchemy.engine.Engine [insertmanyvalues 318/319 (unordered)] {'index__0': 552521, 'actual_elapsed_time__0': 49, 'distance__0': 168, 'dep_delay__0': 29, 'air_time__0': 32, 'cancelled__0': 0, 'airline__0': 'AA', 'dest__0': 'CHS', 'flight_number__0': 1242, 'diverted__0': 0, 'flight_date__0': datetime.datetime(2024, 10, 31, 0, 0), 'dep_time__0': 1129, 'sched_arr_time__0': 1206, 'sched_dep_time__0': 1100, 'tail_number__0': 'N980NN', 'origin__0': 'CLT', 'arr_time__0': 1218, 'arr_delay__0': 12, 'index__1': 566926, 'actual_elapsed_time__1': 106, 'distance__1': 583, 'dep_delay__1': -1, 'air_time__1': 86, 'cancelled__1': 0, 'airline__1': 'AA', 'dest__1': 'GRR', 'flight_number__1': 2947, 'diverted__1': 0, 'flight_date__1': datetime.datetime(2024, 10, 31, 0, 0), 'dep_time__1': 1059, 'sched_arr_time__1': 1303, 'sched_dep_time__1': 1100, 'tail_number__1': 'N901AN', 'origin__1': 'CLT', 'arr_time__1': 1245, 'arr_delay__1': -18, 'index__2': 579433, 'actual_elapsed_time__2': 73, 'distance__2': 331, 'dep_delay__2': -4, 'air_time__2': 52, 'cancelled__2': 0, 'airline__2': '9E', 'dest__2': 'FAY', 'flight_number__2': 5142, 'diverted__2': 0, 'flight_date__2': datetime.datetime(2024, 10, 31, 0, 0), 'dep_time__2': 1056, 'sched_arr_time__2': 1219, 'sched_dep_time__2': 1100 ... 17900 parameters truncated ... 'air_time__997': 244, 'cancelled__997': 0, 'airline__997': 'DL', 'dest__997': 'ATL', 'flight_number__997': 560, 'diverted__997': 0, 'flight_date__997': datetime.datetime(2024, 10, 31, 0, 0), 'dep_time__997': 1551, 'sched_arr_time__997': 2340, 'sched_dep_time__997': 1555, 'tail_number__997': 'N868DN', 'origin__997': 'SEA', 'arr_time__997': 2316, 'arr_delay__997': -24, 'index__998': 186029, 'actual_elapsed_time__998': 117, 'distance__998': 666, 'dep_delay__998': -5, 'air_time__998': 91, 'cancelled__998': 0, 'airline__998': 'DL', 'dest__998': 'PHL', 'flight_number__998': 2842, 'diverted__998': 0, 'flight_date__998': datetime.datetime(2024, 10, 31, 0, 0), 'dep_time__998': 1550, 'sched_arr_time__998': 1749, 'sched_dep_time__998': 1555, 'tail_number__998': 'N673DL', 'origin__998': 'ATL', 'arr_time__998': 1747, 'arr_delay__998': -2, 'index__999': 207271, 'actual_elapsed_time__999': 89, 'distance__999': 453, 'dep_delay__999': -9, 'air_time__999': 75, 'cancelled__999': 0, 'airline__999': 'DL', 'dest__999': 'LIT', 'flight_number__999': 3027, 'diverted__999': 0, 'flight_date__999': datetime.datetime(2024, 10, 31, 0, 0), 'dep_time__999': 1546, 'sched_arr_time__999': 1629, 'sched_dep_time__999': 1555, 'tail_number__999': 'N964AT', 'origin__999': 'ATL', 'arr_time__999': 1615, 'arr_delay__999': -14}
# 2026-02-27 14:24:34,051 INFO sqlalchemy.engine.Engine INSERT INTO below_zero.flights_filtered_1 (index, flight_date, dep_time, sched_dep_time, dep_delay, arr_time, sched_arr_time, arr_delay, airline, tail_number, flight_number, origin, dest, air_time, actual_elapsed_time, distance, cancelled, diverted)  ... 283966 characters truncated ... time__770)s, %(actual_elapsed_time__770)s, %(distance__770)s, %(cancelled__770)s, %(diverted__770)s)
# 2026-02-27 14:24:34,053 INFO sqlalchemy.engine.Engine [insertmanyvalues 319/319 (unordered)] {'index__0': 531760, 'actual_elapsed_time__0': 57, 'distance__0': 257, 'dep_delay__0': 24, 'air_time__0': 42, 'cancelled__0': 0, 'airline__0': 'AA', 'dest__0': 'RIC', 'flight_number__0': 2843, 'diverted__0': 0, 'flight_date__0': datetime.datetime(2024, 10, 31, 0, 0), 'dep_time__0': 1619, 'sched_arr_time__0': 1704, 'sched_dep_time__0': 1555, 'tail_number__0': 'N842NN', 'origin__0': 'CLT', 'arr_time__0': 1716, 'arr_delay__0': 12, 'index__1': 567250, 'actual_elapsed_time__1': 95, 'distance__1': 361, 'dep_delay__1': -4, 'air_time__1': 57, 'cancelled__1': 0, 'airline__1': 'AA', 'dest__1': 'CLT', 'flight_number__1': 2956, 'diverted__1': 0, 'flight_date__1': datetime.datetime(2024, 10, 31, 0, 0), 'dep_time__1': 1551, 'sched_arr_time__1': 1730, 'sched_dep_time__1': 1555, 'tail_number__1': 'N110UW', 'origin__1': 'BWI', 'arr_time__1': 1726, 'arr_delay__1': -4, 'index__2': 301479, 'actual_elapsed_time__2': 110, 'distance__2': 546, 'dep_delay__2': -14, 'air_time__2': 83, 'cancelled__2': 0, 'airline__2': 'F9', 'dest__2': 'BUF', 'flight_number__2': 3062, 'diverted__2': 0, 'flight_date__2': datetime.datetime(2024, 10, 31, 0, 0), 'dep_time__2': 1542, 'sched_arr_time__2': 1737, 'sched_dep_time__2': 1556 ... 13778 parameters truncated ... 'air_time__768': 174, 'cancelled__768': 0, 'airline__768': 'F9', 'dest__768': 'TPA', 'flight_number__768': 1114, 'diverted__768': 0, 'flight_date__768': datetime.datetime(2024, 10, 31, 0, 0), 'dep_time__768': 5, 'sched_arr_time__768': 524, 'sched_dep_time__768': 2359, 'tail_number__768': 'N629FR', 'origin__768': 'DEN', 'arr_time__768': 523, 'arr_delay__768': -1, 'index__769': 494426, 'actual_elapsed_time__769': 170, 'distance__769': 1337, 'dep_delay__769': -8, 'air_time__769': 148, 'cancelled__769': 0, 'airline__769': 'AA', 'dest__769': 'CLT', 'flight_number__769': 1654, 'diverted__769': 0, 'flight_date__769': datetime.datetime(2024, 10, 31, 0, 0), 'dep_time__769': 2351, 'sched_arr_time__769': 509, 'sched_dep_time__769': 2359, 'tail_number__769': 'N468AN', 'origin__769': 'DEN', 'arr_time__769': 441, 'arr_delay__769': -28, 'index__770': 524590, 'actual_elapsed_time__770': 282, 'distance__770': 2125, 'dep_delay__770': 0, 'air_time__770': 234, 'cancelled__770': 0, 'airline__770': 'AA', 'dest__770': 'CLT', 'flight_number__770': 1621, 'diverted__770': 0, 'flight_date__770': datetime.datetime(2024, 10, 31, 0, 0), 'dep_time__770': 2359, 'sched_arr_time__770': 739, 'sched_dep_time__770': 2359, 'tail_number__770': 'N427AN', 'origin__770': 'LAX', 'arr_time__770': 741, 'arr_delay__770': 2}
# 2026-02-27 14:24:34,667 INFO sqlalchemy.engine.Engine COMMIT
# 771

# %% [markdown]
# As next step, get historical weather data using the Meteostat API.
# Based on the notebooks from our API lectures meteostat_daily_fromAPI_toDB_lecture.ipynb and meteostat_hourly_fromAPI_toDB_lecture.ipynb develop new notebook(s) to make API Calls to retrieve the necessary data, and to push it to the project schema in our database. Up to you whether you want to use API endpoints for hourly or daily weather.
# 💡Hint: if the period you selected for the weather event is only a few days long, go for the hourly data. It gives you more granularity.

# %%
airport_staids = {'TPA': 72211,'TLH': 72214,'ATL': 72219,'CLT': 72314}
airport_staids
# Out:
# {'TPA': 72211, 'TLH': 72214, 'ATL': 72219, 'CLT': 72314}

# %%
config = dotenv_values()

api_key = config['x-rapidapi-key'] # align the key label with your .env file

# %%
period_start = "2024-08-01"
period_end = "2024-10-31"

# %%
weather_dict = {'extracted_at':[], 
                'airport_code':[], 
                'station_id':[], 
                'extracted_data':[]
               }

# API CALL daily (station) - for the syntax: see the rapidapi interface

url = "https://meteostat.p.rapidapi.com/stations/daily"

headers = {
        "X-RapidAPI-Key": api_key,
        "X-RapidAPI-Host": "meteostat.p.rapidapi.com"
}

# for-loop for the querystrings
for airport in airport_staids:
   
    querystring = {
        "station":airport_staids[airport]
        ,"start":period_start
        ,"end":period_end
        ,"model":"true"
    }
    
    # making one call with the current querystring
    response = requests.get(url, headers=headers, params=querystring)
                
    # appending data to the dictionary:
    weather_dict['extracted_at'].append(datetime.now())                # timestamp, 
    weather_dict['airport_code'].append(airport)                       # airport code    
    weather_dict['station_id'].append(airport_staids[airport])         # weater Station ID
    weather_dict['extracted_data'].append(json.loads(response.text))   # JSON string

# %%
weather_daily_df = pd.DataFrame(weather_dict)
weather_daily_df
# Out:
#                 extracted_at airport_code  station_id  \
# 0 2026-02-27 15:36:31.135614          TPA       72211
# 1 2026-02-27 15:36:31.605644          TLH       72214
# 2 2026-02-27 15:36:32.109429          ATL       72219
# 3 2026-02-27 15:36:32.661835          CLT       72314
#
#                                       extracted_data
# 0  {'meta': {'generated': '2026-02-27 14:36:28'},...
# 1  {'meta': {'generated': '2026-02-27 14:36:29'},...
# 2  {'meta': {'generated': '2026-02-27 14:36:29'},...
# 3  {'meta': {'generated': '2026-02-27 14:36:30'},...

# %%
url = f'postgresql://{pg_user}:{pg_pass}@{pg_host}:{pg_port}/{pg_db}'
url
# Out:
# 'postgresql://alinakhomich:HmHCUg2AIEiIgiIU@data-analytics-course-2.c8g8r1deus2v.eu-central-1.rds.amazonaws.com:5432/nf_da_onl_en_081225'

# %%
engine = create_engine(
    url,
    connect_args={"options": "-csearch_path=below_zero"},
    echo=True
)

# %%
dtype_dict = {
    'extracted_at':types.DateTime,
    'airport_code': types.String,
    'station_id': types.Integer,
    'extracted_data':postgres_json
             }

# %%
# writing dataframe to DB
weather_daily_df.to_sql(name = 'weather_daily_raw', 
                       con = engine, 
                       schema = "below_zero", # pandas is allowing to specify, in which schema the table shall be created
                       if_exists='replace', 
                       dtype=dtype_dict,
                       index=False
                      )
# Out:
# 2026-02-27 15:41:03,580 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2026-02-27 15:41:03,581 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-02-27 15:41:03,645 INFO sqlalchemy.engine.Engine select current_schema()
# 2026-02-27 15:41:03,645 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-02-27 15:41:03,706 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2026-02-27 15:41:03,706 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-02-27 15:41:03,759 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-02-27 15:41:03,765 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2026-02-27 15:41:03,766 INFO sqlalchemy.engine.Engine [generated in 0.00057s] {'table_name': 'weather_daily_raw', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'below_zero'}
# 2026-02-27 15:41:03,830 INFO sqlalchemy.engine.Engine
# CREATE TABLE below_zero.weather_daily_raw (
# 	extracted_at TIMESTAMP WITHOUT TIME ZONE,
# 	airport_code VARCHAR,
# 	station_id INTEGER,
# 	extracted_data JSON
# )
#
#
# 2026-02-27 15:41:03,831 INFO sqlalchemy.engine.Engine [no key 0.00076s] {}
# 2026-02-27 15:41:03,887 INFO sqlalchemy.engine.Engine INSERT INTO below_zero.weather_daily_raw (extracted_at, airport_code, station_id, extracted_data) VALUES (%(extracted_at__0)s, %(airport_code__0)s, %(station_id__0)s, %(extracted_data__0)s::JSON), (%(extracted_at__1)s, %(airport_code__1)s, %(station_id__1)s, %(extracted_data__1)s::JSON), (%(extracted_at__2)s, %(airport_code__2)s, %(station_id__2)s, %(extracted_data__2)s::JSON), (%(extracted_at__3)s, %(airport_code__3)s, %(station_id__3)s, %(extracted_data__3)s::JSON)
# 2026-02-27 15:41:03,888 INFO sqlalchemy.engine.Engine [generated in 0.00108s (insertmanyvalues) 1/1 (unordered)] {'station_id__0': 72211, 'extracted_at__0': datetime.datetime(2026, 2, 27, 15, 36, 31, 135614), 'extracted_data__0': '{"meta": {"generated": "2026-02-27 14:36:28"}, "data": [{"date": "2024-08-01 00:00:00", "tavg": 28.9, "tmin": 26.1, "tmax": 33.3, "prcp": 11.2, "snow ... (15642 characters truncated) ... 00:00", "tavg": 25.1, "tmin": 21.1, "tmax": 30.0, "prcp": 0.0, "snow": 0.0, "wdir": null, "wspd": 11.2, "wpgt": null, "pres": 1021.0, "tsun": null}]}', 'airport_code__0': 'TPA', 'station_id__1': 72214, 'extracted_at__1': datetime.datetime(2026, 2, 27, 15, 36, 31, 605644), 'extracted_data__1': '{"meta": {"generated": "2026-02-27 14:36:29"}, "data": [{"date": "2024-08-01 00:00:00", "tavg": 28.8, "tmin": 23.9, "tmax": 36.7, "prcp": 0.0, "snow" ... (15659 characters truncated) ... :00:00", "tavg": 24.1, "tmin": 17.8, "tmax": 30.0, "prcp": 0.0, "snow": 0.0, "wdir": null, "wspd": 9.4, "wpgt": null, "pres": 1022.1, "tsun": null}]}', 'airport_code__1': 'TLH', 'station_id__2': 72219, 'extracted_at__2': datetime.datetime(2026, 2, 27, 15, 36, 32, 109429), 'extracted_data__2': '{"meta": {"generated": "2026-02-27 14:36:29"}, "data": [{"date": "2024-08-01 00:00:00", "tavg": 28.5, "tmin": 23.3, "tmax": 34.4, "prcp": 0.0, "snow" ... (15646 characters truncated) ... 00:00", "tavg": 20.9, "tmin": 16.7, "tmax": 26.7, "prcp": 0.0, "snow": 0.0, "wdir": null, "wspd": 10.4, "wpgt": null, "pres": 1023.7, "tsun": null}]}', 'airport_code__2': 'ATL', 'station_id__3': 72314, 'extracted_at__3': datetime.datetime(2026, 2, 27, 15, 36, 32, 661835), 'extracted_data__3': '{"meta": {"generated": "2026-02-27 14:36:30"}, "data": [{"date": "2024-08-01 00:00:00", "tavg": 29.1, "tmin": 23.3, "tmax": 35.0, "prcp": 0.0, "snow" ... (15606 characters truncated) ... :00:00", "tavg": 19.6, "tmin": 12.8, "tmax": 26.7, "prcp": 0.0, "snow": 0.0, "wdir": null, "wspd": 8.3, "wpgt": null, "pres": 1026.4, "tsun": null}]}', 'airport_code__3': 'CLT'}
# 2026-02-27 15:41:03,990 INFO sqlalchemy.engine.Engine COMMIT
# 4
